# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Perceptron

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

# %%
iris = load_iris()

# %%
X = iris.data[:, (2, 3)]
y = (iris.target==0).astype(np.int)

per_clf = Perceptron(random_state=42)
per_clf.fit(X, y)
y_pred = per_clf.predict([[2, 0.5]])

# %%
y_pred
# Out:
# array([1])

# %% [markdown]
# # MLP

# %%
import tensorflow as tf

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %%
feature_columns = tf.contrib.learn.infer_real_valued_columns_from_input(X_train)
dnn_clf = tf.contrib.learn.DNNClassifier(hidden_units=[300, 100], n_classes=10, 
                                        feature_columns=feature_columns)
dnn_clf.fit(x=X_train, y=y_train, batch_size=50, steps=40000)
# Out:
# WARNING:tensorflow:From <ipython-input-8-fb661028591a>:1: infer_real_valued_columns_from_input (from tensorflow.contrib.learn.python.learn.estimators.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please specify feature columns explicitly.
# WARNING:tensorflow:From /Users/liufang/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py:143: setup_train_data_feeder (from tensorflow.contrib.learn.python.learn.learn_io.data_feeder) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.
# WARNING:tensorflow:From /Users/liufang/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/learn_io/data_feeder.py:100: extract_pandas_data (from tensorflow.contrib.learn.python.learn.learn_io.pandas_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please access pandas data directly.
# WARNING:tensorflow:From /Users/liufang/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/learn_io/data_feeder.py:159: DataFeeder.__init__ (from tensorflow.contrib.learn.python.learn.learn_io.data_feeder) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.
# WARNING:tensorflow:From /Users/liufang/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/learn_io/data_feeder.py:340: check_array (from tensorflow.contrib.learn.python.learn.learn_io.data_feeder) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please convert numpy dtypes explicitly.
# WARNING:tensorflow:From /Users/liufang/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py:183: infer_real_valued_columns_from_input_fn (from tensorflow.contrib.learn.python.learn.estimators.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please specify feature columns explicitly.
# WARNING:tensorflow:From /Users/liufang/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:378: multi_class_head (from tensorflow.contrib.learn.python.learn.estimators.head) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.contrib.estimator.*_head.
# WARNING:tensorflow:From /Users/liufang/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py:1180: BaseEstimator.__init__ (from tensorflow.contrib.learn.python.learn.estimators.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please replace uses of any Estimator from tf.contrib.learn with an Estimator from tf.estimator.*
# WARNING:tensorflow:From /Users/liufang/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py:428: RunConfig.__init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/6g/q2scz4c92pdf777kd5gg_kpm0000gn/T/tmpd_umpgk2
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x12ad226d8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/var/folders/6g/q2scz4c92pdf777kd5gg_kpm0000gn/T/tmpd_umpgk2'}
# WARNING:tensorflow:From <ipython-input-8-fb661028591a>:4: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-8-fb661028591a>:4: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-8-fb661028591a>:4: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with batch_size is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/liufang/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py:509: SKCompat.__init__ (from tensorflow.contrib.learn.python.learn.estimators.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to the Estimator interface.
# WARNING:tensorflow:From /Users/liufang/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/learn_io/data_feeder.py:102: extract_pandas_labels (from tensorflow.contrib.learn.python.learn.learn_io.pandas_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please access pandas data directly.
# WARNING:tensorflow:From /Users/liufang/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:678: ModelFnOps.__new__ (from tensorflow.contrib.learn.python.learn.estimators.model_fn) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.EstimatorSpec. You can use the `estimator_spec` method to create an equivalent one.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/6g/q2scz4c92pdf777kd5gg_kpm0000gn/T/tmpd_umpgk2/model.ckpt.
# INFO:tensorflow:loss = 2.3029907, step = 1
# INFO:tensorflow:global_step/sec: 281.378
# INFO:tensorflow:loss = 0.30503023, step = 101 (0.357 sec)
# INFO:tensorflow:global_step/sec: 303.488
# INFO:tensorflow:loss = 0.2714154, step = 201 (0.330 sec)
# INFO:tensorflow:global_step/sec: 303.155
# INFO:tensorflow:loss = 0.3741948, step = 301 (0.331 sec)
# INFO:tensorflow:global_step/sec: 290.515
# INFO:tensorflow:loss = 0.24260691, step = 401 (0.343 sec)
# INFO:tensorflow:global_step/sec: 300.972
# INFO:tensorflow:loss = 0.2527277, step = 501 (0.333 sec)
# INFO:tensorflow:global_step/sec: 293.906
# INFO:tensorflow:loss = 0.07172419, step = 601 (0.340 sec)
# INFO:tensorflow:global_step/sec: 296.624
# INFO:tensorflow:loss = 0.1208395, step = 701 (0.337 sec)
# INFO:tensorflow:global_step/sec: 285.945
# INFO:tensorflow:loss = 0.23163195, step = 801 (0.350 sec)
# INFO:tensorflow:global_step/sec: 299.396
# INFO:tensorflow:loss = 0.11551095, step = 901 (0.334 sec)
# INFO:tensorflow:global_step/sec: 302.271
# INFO:tensorflow:loss = 0.19301988, step = 1001 (0.331 sec)
# INFO:tensorflow:global_step/sec: 300.736
# INFO:tensorflow:loss = 0.14930147, step = 1101 (0.333 sec)
# INFO:tensorflow:global_step/sec: 299.22
# INFO:tensorflow:loss = 0.13971743, step = 1201 (0.334 sec)
# INFO:tensorflow:global_step/sec: 295.092
# INFO:tensorflow:loss = 0.16362509, step = 1301 (0.339 sec)
# INFO:tensorflow:global_step/sec: 293.978
# INFO:tensorflow:loss = 0.09787001, step = 1401 (0.341 sec)
# INFO:tensorflow:global_step/sec: 307.462
# INFO:tensorflow:loss = 0.087699674, step = 1501 (0.325 sec)
# INFO:tensorflow:global_step/sec: 299.767
# INFO:tensorflow:loss = 0.12586343, step = 1601 (0.334 sec)
# INFO:tensorflow:global_step/sec: 297.773
# INFO:tensorflow:loss = 0.031842664, step = 1701 (0.336 sec)
# INFO:tensorflow:global_step/sec: 303.312
# INFO:tensorflow:loss = 0.1581376, step = 1801 (0.330 sec)
# INFO:tensorflow:global_step/sec: 304.753
# INFO:tensorflow:loss = 0.08548667, step = 1901 (0.328 sec)
# INFO:tensorflow:global_step/sec: 295.786
# INFO:tensorflow:loss = 0.13121699, step = 2001 (0.338 sec)
# INFO:tensorflow:global_step/sec: 301.75
# INFO:tensorflow:loss = 0.024735678, step = 2101 (0.331 sec)
# INFO:tensorflow:global_step/sec: 298.188
# INFO:tensorflow:loss = 0.03458581, step = 2201 (0.335 sec)
# INFO:tensorflow:global_step/sec: 292.934
# INFO:tensorflow:loss = 0.048459142, step = 2301 (0.342 sec)
# INFO:tensorflow:global_step/sec: 311.803
# INFO:tensorflow:loss = 0.036927518, step = 2401 (0.321 sec)
# INFO:tensorflow:global_step/sec: 297.171
# INFO:tensorflow:loss = 0.08775753, step = 2501 (0.337 sec)
# INFO:tensorflow:global_step/sec: 299.056
# INFO:tensorflow:loss = 0.062588654, step = 2601 (0.335 sec)
# INFO:tensorflow:global_step/sec: 301.141
# INFO:tensorflow:loss = 0.011067363, step = 2701 (0.332 sec)
# INFO:tensorflow:global_step/sec: 297.009
# INFO:tensorflow:loss = 0.049605552, step = 2801 (0.337 sec)
# INFO:tensorflow:global_step/sec: 297.02
# INFO:tensorflow:loss = 0.10417277, step = 2901 (0.337 sec)
# INFO:tensorflow:global_step/sec: 305.031
# INFO:tensorflow:loss = 0.028982494, step = 3001 (0.328 sec)
# INFO:tensorflow:global_step/sec: 295.321
# INFO:tensorflow:loss = 0.055649705, step = 3101 (0.338 sec)
# INFO:tensorflow:global_step/sec: 295.485
# INFO:tensorflow:loss = 0.011536556, step = 3201 (0.338 sec)
# INFO:tensorflow:global_step/sec: 298.112
# INFO:tensorflow:loss = 0.027094694, step = 3301 (0.335 sec)
# INFO:tensorflow:global_step/sec: 302.088
# INFO:tensorflow:loss = 0.17086852, step = 3401 (0.331 sec)
# INFO:tensorflow:global_step/sec: 303.149
# INFO:tensorflow:loss = 0.09999971, step = 3501 (0.330 sec)
# INFO:tensorflow:global_step/sec: 307.209
# INFO:tensorflow:loss = 0.18187664, step = 3601 (0.326 sec)
# INFO:tensorflow:global_step/sec: 291.291
# INFO:tensorflow:loss = 0.044634923, step = 3701 (0.343 sec)
# INFO:tensorflow:global_step/sec: 298.712
# INFO:tensorflow:loss = 0.007083882, step = 3801 (0.335 sec)
# INFO:tensorflow:global_step/sec: 300.162
# INFO:tensorflow:loss = 0.04277241, step = 3901 (0.333 sec)
# INFO:tensorflow:global_step/sec: 301.424
# INFO:tensorflow:loss = 0.11896183, step = 4001 (0.332 sec)
# INFO:tensorflow:global_step/sec: 310.405
# INFO:tensorflow:loss = 0.03360695, step = 4101 (0.322 sec)
# INFO:tensorflow:global_step/sec: 299.616
# INFO:tensorflow:loss = 0.055118743, step = 4201 (0.334 sec)
# INFO:tensorflow:global_step/sec: 303.642
# INFO:tensorflow:loss = 0.15377553, step = 4301 (0.329 sec)
# INFO:tensorflow:global_step/sec: 286.103
# INFO:tensorflow:loss = 0.07643109, step = 4401 (0.350 sec)
# INFO:tensorflow:global_step/sec: 306.459
# INFO:tensorflow:loss = 0.022725916, step = 4501 (0.326 sec)
# INFO:tensorflow:global_step/sec: 301.828
# INFO:tensorflow:loss = 0.01961272, step = 4601 (0.332 sec)
# INFO:tensorflow:global_step/sec: 297.23
# INFO:tensorflow:loss = 0.009860835, step = 4701 (0.337 sec)
# INFO:tensorflow:global_step/sec: 303.516
# INFO:tensorflow:loss = 0.015830081, step = 4801 (0.329 sec)
# INFO:tensorflow:global_step/sec: 297.587
# INFO:tensorflow:loss = 0.073409535, step = 4901 (0.336 sec)
# INFO:tensorflow:global_step/sec: 297.752
# INFO:tensorflow:loss = 0.043517176, step = 5001 (0.336 sec)
# INFO:tensorflow:global_step/sec: 303.605
# INFO:tensorflow:loss = 0.0072186776, step = 5101 (0.329 sec)
# INFO:tensorflow:global_step/sec: 298.063
# INFO:tensorflow:loss = 0.03122865, step = 5201 (0.336 sec)
# INFO:tensorflow:global_step/sec: 292.039
# INFO:tensorflow:loss = 0.018944172, step = 5301 (0.342 sec)
# INFO:tensorflow:global_step/sec: 297.86
# INFO:tensorflow:loss = 0.030544521, step = 5401 (0.336 sec)
# INFO:tensorflow:global_step/sec: 288.69
# INFO:tensorflow:loss = 0.02006322, step = 5501 (0.346 sec)
# INFO:tensorflow:global_step/sec: 296.523
# INFO:tensorflow:loss = 0.08951998, step = 5601 (0.337 sec)
# INFO:tensorflow:global_step/sec: 302.463
# INFO:tensorflow:loss = 0.017163213, step = 5701 (0.331 sec)
# INFO:tensorflow:global_step/sec: 277.968
# INFO:tensorflow:loss = 0.008251717, step = 5801 (0.360 sec)
# INFO:tensorflow:global_step/sec: 301.996
# INFO:tensorflow:loss = 0.06315859, step = 5901 (0.331 sec)
# INFO:tensorflow:global_step/sec: 302.455
# INFO:tensorflow:loss = 0.08739904, step = 6001 (0.331 sec)
# INFO:tensorflow:global_step/sec: 299.305
# INFO:tensorflow:loss = 0.02927551, step = 6101 (0.334 sec)
# INFO:tensorflow:global_step/sec: 301.994
# INFO:tensorflow:loss = 0.022372484, step = 6201 (0.331 sec)
# INFO:tensorflow:global_step/sec: 302.433
# INFO:tensorflow:loss = 0.061143786, step = 6301 (0.330 sec)
# INFO:tensorflow:global_step/sec: 303.461
# INFO:tensorflow:loss = 0.026245348, step = 6401 (0.330 sec)
# INFO:tensorflow:global_step/sec: 298.653
# INFO:tensorflow:loss = 0.0059096124, step = 6501 (0.334 sec)
# INFO:tensorflow:global_step/sec: 301.13
# INFO:tensorflow:loss = 0.014257108, step = 6601 (0.332 sec)
# INFO:tensorflow:global_step/sec: 304.999
# INFO:tensorflow:loss = 0.011916446, step = 6701 (0.328 sec)
# INFO:tensorflow:global_step/sec: 307.18
# INFO:tensorflow:loss = 0.008820993, step = 6801 (0.326 sec)
# INFO:tensorflow:global_step/sec: 301.871
# INFO:tensorflow:loss = 0.011121421, step = 6901 (0.331 sec)
# INFO:tensorflow:global_step/sec: 307.69
# INFO:tensorflow:loss = 0.029482253, step = 7001 (0.325 sec)
# INFO:tensorflow:global_step/sec: 301.064
# INFO:tensorflow:loss = 0.003020225, step = 7101 (0.333 sec)
# INFO:tensorflow:global_step/sec: 302.283
# INFO:tensorflow:loss = 0.04748949, step = 7201 (0.330 sec)
# INFO:tensorflow:global_step/sec: 300.522
# INFO:tensorflow:loss = 0.005383985, step = 7301 (0.333 sec)
# INFO:tensorflow:global_step/sec: 302.979
# INFO:tensorflow:loss = 0.021793313, step = 7401 (0.330 sec)
# INFO:tensorflow:global_step/sec: 289.937
# INFO:tensorflow:loss = 0.0037867054, step = 7501 (0.345 sec)
# INFO:tensorflow:global_step/sec: 297.322
# INFO:tensorflow:loss = 0.027573314, step = 7601 (0.337 sec)
# INFO:tensorflow:global_step/sec: 294.045
# INFO:tensorflow:loss = 0.015816841, step = 7701 (0.340 sec)
# INFO:tensorflow:global_step/sec: 300.633
# INFO:tensorflow:loss = 0.003851517, step = 7801 (0.333 sec)
# INFO:tensorflow:global_step/sec: 271.181
# INFO:tensorflow:loss = 0.011768052, step = 7901 (0.369 sec)
# INFO:tensorflow:global_step/sec: 274.064
# INFO:tensorflow:loss = 0.0024573694, step = 8001 (0.365 sec)
# INFO:tensorflow:global_step/sec: 273.603
# INFO:tensorflow:loss = 0.01639925, step = 8101 (0.367 sec)
# INFO:tensorflow:global_step/sec: 267.77
# INFO:tensorflow:loss = 0.023831435, step = 8201 (0.372 sec)
# INFO:tensorflow:global_step/sec: 291.293
# INFO:tensorflow:loss = 0.039342947, step = 8301 (0.343 sec)
# INFO:tensorflow:global_step/sec: 279.172
# INFO:tensorflow:loss = 0.009702112, step = 8401 (0.358 sec)
# INFO:tensorflow:global_step/sec: 262.292
# INFO:tensorflow:loss = 0.0043081357, step = 8501 (0.382 sec)
# INFO:tensorflow:global_step/sec: 283.645
# INFO:tensorflow:loss = 0.005725788, step = 8601 (0.352 sec)
# INFO:tensorflow:global_step/sec: 288.711
# INFO:tensorflow:loss = 0.0032411434, step = 8701 (0.347 sec)
# INFO:tensorflow:global_step/sec: 299.779
# INFO:tensorflow:loss = 0.0110906735, step = 8801 (0.333 sec)
# INFO:tensorflow:global_step/sec: 299.067
# INFO:tensorflow:loss = 0.0029251128, step = 8901 (0.334 sec)
# INFO:tensorflow:global_step/sec: 298.109
# INFO:tensorflow:loss = 0.0053105596, step = 9001 (0.336 sec)
# INFO:tensorflow:global_step/sec: 277.667
# INFO:tensorflow:loss = 0.008353011, step = 9101 (0.360 sec)
# INFO:tensorflow:global_step/sec: 288.185
# INFO:tensorflow:loss = 0.0045163054, step = 9201 (0.347 sec)
# INFO:tensorflow:global_step/sec: 285.021
# INFO:tensorflow:loss = 0.0070676235, step = 9301 (0.351 sec)
# INFO:tensorflow:global_step/sec: 306.124
# INFO:tensorflow:loss = 0.052613962, step = 9401 (0.327 sec)
# INFO:tensorflow:global_step/sec: 277.616
# INFO:tensorflow:loss = 0.0050026663, step = 9501 (0.360 sec)
# INFO:tensorflow:global_step/sec: 291.757
# INFO:tensorflow:loss = 0.019841576, step = 9601 (0.343 sec)
# INFO:tensorflow:global_step/sec: 279.125
# INFO:tensorflow:loss = 0.006016429, step = 9701 (0.358 sec)
# INFO:tensorflow:global_step/sec: 286.427
# INFO:tensorflow:loss = 0.0037785145, step = 9801 (0.349 sec)
# INFO:tensorflow:global_step/sec: 285.448
# INFO:tensorflow:loss = 0.017033314, step = 9901 (0.351 sec)
# INFO:tensorflow:global_step/sec: 299.903
# INFO:tensorflow:loss = 0.0070566996, step = 10001 (0.333 sec)
# INFO:tensorflow:global_step/sec: 300.855
# INFO:tensorflow:loss = 0.0047254316, step = 10101 (0.332 sec)
# INFO:tensorflow:global_step/sec: 276.26
# INFO:tensorflow:loss = 0.0063539203, step = 10201 (0.362 sec)
# INFO:tensorflow:global_step/sec: 282.396
# INFO:tensorflow:loss = 0.0024290017, step = 10301 (0.354 sec)
# INFO:tensorflow:global_step/sec: 269.089
# INFO:tensorflow:loss = 0.004866338, step = 10401 (0.372 sec)
# INFO:tensorflow:global_step/sec: 279.89
# INFO:tensorflow:loss = 0.0026928526, step = 10501 (0.357 sec)
# INFO:tensorflow:global_step/sec: 268.313
# INFO:tensorflow:loss = 0.004768166, step = 10601 (0.375 sec)
# INFO:tensorflow:global_step/sec: 277.719
# INFO:tensorflow:loss = 0.01802883, step = 10701 (0.358 sec)
# INFO:tensorflow:global_step/sec: 297.554
# INFO:tensorflow:loss = 0.00537789, step = 10801 (0.336 sec)
# INFO:tensorflow:global_step/sec: 301.481
# INFO:tensorflow:loss = 0.0011166753, step = 10901 (0.332 sec)
# INFO:tensorflow:global_step/sec: 276.371
# INFO:tensorflow:loss = 0.028874345, step = 11001 (0.362 sec)
# INFO:tensorflow:global_step/sec: 301.668
# INFO:tensorflow:loss = 0.009197776, step = 11101 (0.332 sec)
# INFO:tensorflow:global_step/sec: 278.943
# INFO:tensorflow:loss = 0.0005983342, step = 11201 (0.360 sec)
# INFO:tensorflow:global_step/sec: 275.765
# INFO:tensorflow:loss = 0.0047277994, step = 11301 (0.363 sec)
# INFO:tensorflow:global_step/sec: 287.281
# INFO:tensorflow:loss = 0.0058962037, step = 11401 (0.347 sec)
# INFO:tensorflow:global_step/sec: 294.856
# INFO:tensorflow:loss = 0.017586872, step = 11501 (0.339 sec)
# INFO:tensorflow:global_step/sec: 302.929
# INFO:tensorflow:loss = 0.0006503715, step = 11601 (0.330 sec)
# INFO:tensorflow:global_step/sec: 275.976
# INFO:tensorflow:loss = 0.0021350763, step = 11701 (0.362 sec)
# INFO:tensorflow:global_step/sec: 289.641
# INFO:tensorflow:loss = 0.0008082022, step = 11801 (0.345 sec)
# INFO:tensorflow:global_step/sec: 303.733
# INFO:tensorflow:loss = 0.0056342906, step = 11901 (0.329 sec)
# INFO:tensorflow:global_step/sec: 289.9
# INFO:tensorflow:loss = 0.00015329865, step = 12001 (0.345 sec)
# INFO:tensorflow:global_step/sec: 297.937
# INFO:tensorflow:loss = 0.0016409472, step = 12101 (0.336 sec)
# INFO:tensorflow:global_step/sec: 286.79
# INFO:tensorflow:loss = 0.0044011683, step = 12201 (0.349 sec)
# INFO:tensorflow:global_step/sec: 275.869
# INFO:tensorflow:loss = 0.0028304413, step = 12301 (0.365 sec)
# INFO:tensorflow:global_step/sec: 291.542
# INFO:tensorflow:loss = 0.00023822379, step = 12401 (0.340 sec)
# INFO:tensorflow:global_step/sec: 280.25
# INFO:tensorflow:loss = 0.003155247, step = 12501 (0.357 sec)
# INFO:tensorflow:global_step/sec: 286.429
# INFO:tensorflow:loss = 0.0014273333, step = 12601 (0.349 sec)
# INFO:tensorflow:global_step/sec: 276.952
# INFO:tensorflow:loss = 0.0038923922, step = 12701 (0.361 sec)
# INFO:tensorflow:global_step/sec: 291.84
# INFO:tensorflow:loss = 0.006281085, step = 12801 (0.343 sec)
# INFO:tensorflow:global_step/sec: 301.744
# INFO:tensorflow:loss = 0.003491378, step = 12901 (0.331 sec)
# INFO:tensorflow:global_step/sec: 254.941
# INFO:tensorflow:loss = 0.0025336824, step = 13001 (0.392 sec)
# INFO:tensorflow:global_step/sec: 296.245
# INFO:tensorflow:loss = 0.0019392442, step = 13101 (0.338 sec)
# INFO:tensorflow:global_step/sec: 297.985
# INFO:tensorflow:loss = 0.0022637763, step = 13201 (0.335 sec)
# INFO:tensorflow:global_step/sec: 270.813
# INFO:tensorflow:loss = 0.0058243996, step = 13301 (0.369 sec)
# INFO:tensorflow:global_step/sec: 272.273
# INFO:tensorflow:loss = 0.007116948, step = 13401 (0.367 sec)
# INFO:tensorflow:global_step/sec: 299.955
# INFO:tensorflow:loss = 0.0021397858, step = 13501 (0.333 sec)
# INFO:tensorflow:global_step/sec: 280.715
# INFO:tensorflow:loss = 0.0030841841, step = 13601 (0.357 sec)
# INFO:tensorflow:global_step/sec: 281.484
# INFO:tensorflow:loss = 0.002156728, step = 13701 (0.356 sec)
# INFO:tensorflow:global_step/sec: 288.135
# INFO:tensorflow:loss = 0.0060361843, step = 13801 (0.346 sec)
# INFO:tensorflow:global_step/sec: 274.79
# INFO:tensorflow:loss = 0.0020747664, step = 13901 (0.364 sec)
# INFO:tensorflow:global_step/sec: 291.208
# INFO:tensorflow:loss = 0.002077111, step = 14001 (0.344 sec)
# INFO:tensorflow:global_step/sec: 261.324
# INFO:tensorflow:loss = 0.010419355, step = 14101 (0.382 sec)
# INFO:tensorflow:global_step/sec: 295.866
# INFO:tensorflow:loss = 0.0038562268, step = 14201 (0.339 sec)
# INFO:tensorflow:global_step/sec: 284.414
# INFO:tensorflow:loss = 0.0010831358, step = 14301 (0.351 sec)
# INFO:tensorflow:global_step/sec: 283.157
# INFO:tensorflow:loss = 0.0006161942, step = 14401 (0.353 sec)
# INFO:tensorflow:global_step/sec: 283.512
# INFO:tensorflow:loss = 0.0007118242, step = 14501 (0.353 sec)
# INFO:tensorflow:global_step/sec: 294.665
# INFO:tensorflow:loss = 0.0043032533, step = 14601 (0.339 sec)
# INFO:tensorflow:global_step/sec: 278.124
# INFO:tensorflow:loss = 0.0019775569, step = 14701 (0.359 sec)
# INFO:tensorflow:global_step/sec: 280.904
# INFO:tensorflow:loss = 0.0007132346, step = 14801 (0.356 sec)
# INFO:tensorflow:global_step/sec: 270.729
# INFO:tensorflow:loss = 0.002098291, step = 14901 (0.370 sec)
# INFO:tensorflow:global_step/sec: 280.734
# INFO:tensorflow:loss = 0.0006782649, step = 15001 (0.356 sec)
# INFO:tensorflow:global_step/sec: 273.001
# INFO:tensorflow:loss = 0.00165671, step = 15101 (0.366 sec)
# INFO:tensorflow:global_step/sec: 292.931
# INFO:tensorflow:loss = 0.0018905848, step = 15201 (0.341 sec)
# INFO:tensorflow:global_step/sec: 300.688
# INFO:tensorflow:loss = 0.0014026422, step = 15301 (0.332 sec)
# INFO:tensorflow:global_step/sec: 271.716
# INFO:tensorflow:loss = 0.0014559537, step = 15401 (0.368 sec)
# INFO:tensorflow:global_step/sec: 306.058
# INFO:tensorflow:loss = 0.0049187597, step = 15501 (0.327 sec)
# INFO:tensorflow:global_step/sec: 312.373
# INFO:tensorflow:loss = 0.003546372, step = 15601 (0.320 sec)
# INFO:tensorflow:global_step/sec: 309.942
# INFO:tensorflow:loss = 0.0053824377, step = 15701 (0.323 sec)
# INFO:tensorflow:global_step/sec: 308.949
# INFO:tensorflow:loss = 0.0011780794, step = 15801 (0.323 sec)
# INFO:tensorflow:global_step/sec: 300.71
# INFO:tensorflow:loss = 0.0005060042, step = 15901 (0.333 sec)
# INFO:tensorflow:global_step/sec: 306.069
# INFO:tensorflow:loss = 0.0057207686, step = 16001 (0.327 sec)
# INFO:tensorflow:global_step/sec: 304.084
# INFO:tensorflow:loss = 0.0033685362, step = 16101 (0.329 sec)
# INFO:tensorflow:global_step/sec: 307.035
# INFO:tensorflow:loss = 0.00012631719, step = 16201 (0.325 sec)
# INFO:tensorflow:global_step/sec: 270.642
# INFO:tensorflow:loss = 0.0047068717, step = 16301 (0.370 sec)
# INFO:tensorflow:global_step/sec: 288.48
# INFO:tensorflow:loss = 0.00086810126, step = 16401 (0.347 sec)
# INFO:tensorflow:global_step/sec: 285.447
# INFO:tensorflow:loss = 0.003255375, step = 16501 (0.350 sec)
# INFO:tensorflow:global_step/sec: 303.176
# INFO:tensorflow:loss = 0.0023274454, step = 16601 (0.330 sec)
# INFO:tensorflow:global_step/sec: 300.874
# INFO:tensorflow:loss = 0.0018341074, step = 16701 (0.333 sec)
# INFO:tensorflow:global_step/sec: 304.937
# INFO:tensorflow:loss = 0.0030761885, step = 16801 (0.329 sec)
# INFO:tensorflow:global_step/sec: 290.964
# INFO:tensorflow:loss = 0.0026407968, step = 16901 (0.343 sec)
# INFO:tensorflow:global_step/sec: 281.38
# INFO:tensorflow:loss = 0.0072444724, step = 17001 (0.355 sec)
# INFO:tensorflow:global_step/sec: 289.71
# INFO:tensorflow:loss = 0.00051994366, step = 17101 (0.346 sec)
# INFO:tensorflow:global_step/sec: 260.385
# INFO:tensorflow:loss = 0.0024741632, step = 17201 (0.383 sec)
# INFO:tensorflow:global_step/sec: 312.692
# INFO:tensorflow:loss = 0.0017803877, step = 17301 (0.320 sec)
# INFO:tensorflow:global_step/sec: 304.875
# INFO:tensorflow:loss = 0.001226087, step = 17401 (0.328 sec)
# INFO:tensorflow:global_step/sec: 294.086
# INFO:tensorflow:loss = 0.0010797728, step = 17501 (0.340 sec)
# INFO:tensorflow:global_step/sec: 290.547
# INFO:tensorflow:loss = 0.0006754696, step = 17601 (0.344 sec)
# INFO:tensorflow:global_step/sec: 277.262
# INFO:tensorflow:loss = 0.00086242857, step = 17701 (0.361 sec)
# INFO:tensorflow:global_step/sec: 288.961
# INFO:tensorflow:loss = 0.0003071396, step = 17801 (0.346 sec)
# INFO:tensorflow:global_step/sec: 290.904
# INFO:tensorflow:loss = 0.001888949, step = 17901 (0.344 sec)
# INFO:tensorflow:global_step/sec: 289.078
# INFO:tensorflow:loss = 0.00071353314, step = 18001 (0.345 sec)
# INFO:tensorflow:global_step/sec: 303.312
# INFO:tensorflow:loss = 0.0012869824, step = 18101 (0.330 sec)
# INFO:tensorflow:global_step/sec: 275.544
# INFO:tensorflow:loss = 0.0043607466, step = 18201 (0.363 sec)
# INFO:tensorflow:global_step/sec: 289.547
# INFO:tensorflow:loss = 0.0123880515, step = 18301 (0.345 sec)
# INFO:tensorflow:global_step/sec: 286.662
# INFO:tensorflow:loss = 0.0016739297, step = 18401 (0.350 sec)
# INFO:tensorflow:global_step/sec: 283.033
# INFO:tensorflow:loss = 0.001924794, step = 18501 (0.351 sec)
# INFO:tensorflow:global_step/sec: 309.938
# INFO:tensorflow:loss = 0.002958334, step = 18601 (0.323 sec)
# INFO:tensorflow:global_step/sec: 305.173
# INFO:tensorflow:loss = 0.0010077518, step = 18701 (0.328 sec)
# INFO:tensorflow:global_step/sec: 310.249
# INFO:tensorflow:loss = 0.001627122, step = 18801 (0.322 sec)
# INFO:tensorflow:global_step/sec: 312.775
# INFO:tensorflow:loss = 0.0027217655, step = 18901 (0.320 sec)
# INFO:tensorflow:global_step/sec: 265.261
# INFO:tensorflow:loss = 0.0012868458, step = 19001 (0.377 sec)
# INFO:tensorflow:global_step/sec: 269.871
# INFO:tensorflow:loss = 0.0006214461, step = 19101 (0.371 sec)
# INFO:tensorflow:global_step/sec: 289.442
# INFO:tensorflow:loss = 0.0008573002, step = 19201 (0.345 sec)
# INFO:tensorflow:global_step/sec: 282.045
# INFO:tensorflow:loss = 0.0057216943, step = 19301 (0.355 sec)
# INFO:tensorflow:global_step/sec: 290.054
# INFO:tensorflow:loss = 0.0010521746, step = 19401 (0.345 sec)
# INFO:tensorflow:global_step/sec: 300.708
# INFO:tensorflow:loss = 0.0020242187, step = 19501 (0.333 sec)
# INFO:tensorflow:global_step/sec: 298.294
# INFO:tensorflow:loss = 0.000405259, step = 19601 (0.335 sec)
# INFO:tensorflow:global_step/sec: 293.161
# INFO:tensorflow:loss = 5.2538697e-05, step = 19701 (0.341 sec)
# INFO:tensorflow:global_step/sec: 299.683
# INFO:tensorflow:loss = 0.0003913352, step = 19801 (0.334 sec)
# INFO:tensorflow:global_step/sec: 309.81
# INFO:tensorflow:loss = 0.0020716346, step = 19901 (0.323 sec)
# INFO:tensorflow:global_step/sec: 288.806
# INFO:tensorflow:loss = 0.0023585365, step = 20001 (0.346 sec)
# INFO:tensorflow:global_step/sec: 293.032
# INFO:tensorflow:loss = 0.00051779544, step = 20101 (0.341 sec)
# INFO:tensorflow:global_step/sec: 306.411
# INFO:tensorflow:loss = 0.0020063128, step = 20201 (0.326 sec)
# INFO:tensorflow:global_step/sec: 309.95
# INFO:tensorflow:loss = 0.0011007171, step = 20301 (0.322 sec)
# INFO:tensorflow:global_step/sec: 282.737
# INFO:tensorflow:loss = 0.00031300558, step = 20401 (0.354 sec)
# INFO:tensorflow:global_step/sec: 308.761
# INFO:tensorflow:loss = 0.0011316965, step = 20501 (0.324 sec)
# INFO:tensorflow:global_step/sec: 279.601
# INFO:tensorflow:loss = 0.00091961084, step = 20601 (0.357 sec)
# INFO:tensorflow:global_step/sec: 296.547
# INFO:tensorflow:loss = 0.00092031347, step = 20701 (0.338 sec)
# INFO:tensorflow:global_step/sec: 273.94
# INFO:tensorflow:loss = 0.0017384136, step = 20801 (0.366 sec)
# INFO:tensorflow:global_step/sec: 282.994
# INFO:tensorflow:loss = 0.0012408219, step = 20901 (0.352 sec)
# INFO:tensorflow:global_step/sec: 287.693
# INFO:tensorflow:loss = 0.0017887912, step = 21001 (0.348 sec)
# INFO:tensorflow:global_step/sec: 275.44
# INFO:tensorflow:loss = 0.0009019755, step = 21101 (0.363 sec)
# INFO:tensorflow:global_step/sec: 292.065
# INFO:tensorflow:loss = 0.0041361004, step = 21201 (0.342 sec)
# INFO:tensorflow:global_step/sec: 269.233
# INFO:tensorflow:loss = 0.0006380111, step = 21301 (0.372 sec)
# INFO:tensorflow:global_step/sec: 307.415
# INFO:tensorflow:loss = 0.001962, step = 21401 (0.325 sec)
# INFO:tensorflow:global_step/sec: 304.813
# INFO:tensorflow:loss = 0.00022790548, step = 21501 (0.328 sec)
# INFO:tensorflow:global_step/sec: 297.263
# INFO:tensorflow:loss = 0.0015611222, step = 21601 (0.337 sec)
# INFO:tensorflow:global_step/sec: 305.017
# INFO:tensorflow:loss = 0.00083000324, step = 21701 (0.328 sec)
# INFO:tensorflow:global_step/sec: 310.869
# INFO:tensorflow:loss = 0.00041544906, step = 21801 (0.321 sec)
# INFO:tensorflow:global_step/sec: 304.964
# INFO:tensorflow:loss = 0.0006645567, step = 21901 (0.328 sec)
# INFO:tensorflow:global_step/sec: 273.967
# INFO:tensorflow:loss = 3.3247677e-05, step = 22001 (0.366 sec)
# INFO:tensorflow:global_step/sec: 303.448
# INFO:tensorflow:loss = 0.00029099366, step = 22101 (0.329 sec)
# INFO:tensorflow:global_step/sec: 294.769
# INFO:tensorflow:loss = 0.0010781277, step = 22201 (0.341 sec)
# INFO:tensorflow:global_step/sec: 287.475
# INFO:tensorflow:loss = 0.0013968258, step = 22301 (0.347 sec)
# INFO:tensorflow:global_step/sec: 281.031
# INFO:tensorflow:loss = 0.0019939377, step = 22401 (0.355 sec)
# INFO:tensorflow:global_step/sec: 299.139
# INFO:tensorflow:loss = 0.0011646057, step = 22501 (0.334 sec)
# INFO:tensorflow:global_step/sec: 304.575
# INFO:tensorflow:loss = 0.002743789, step = 22601 (0.328 sec)
# INFO:tensorflow:global_step/sec: 311.513
# INFO:tensorflow:loss = 0.0009956111, step = 22701 (0.321 sec)
# INFO:tensorflow:global_step/sec: 292.343
# INFO:tensorflow:loss = 0.0009377587, step = 22801 (0.342 sec)
# INFO:tensorflow:global_step/sec: 295.647
# INFO:tensorflow:loss = 0.0020512722, step = 22901 (0.338 sec)
# INFO:tensorflow:global_step/sec: 280.367
# INFO:tensorflow:loss = 0.0005449603, step = 23001 (0.357 sec)
# INFO:tensorflow:global_step/sec: 280.74
# INFO:tensorflow:loss = 0.0041606757, step = 23101 (0.356 sec)
# INFO:tensorflow:global_step/sec: 302.4
# INFO:tensorflow:loss = 0.0022841848, step = 23201 (0.331 sec)
# INFO:tensorflow:global_step/sec: 281.634
# INFO:tensorflow:loss = 0.0020707743, step = 23301 (0.355 sec)
# INFO:tensorflow:global_step/sec: 275.689
# INFO:tensorflow:loss = 0.00055972784, step = 23401 (0.363 sec)
# INFO:tensorflow:global_step/sec: 274.474
# INFO:tensorflow:loss = 0.00068049727, step = 23501 (0.364 sec)
# INFO:tensorflow:global_step/sec: 288.834
# INFO:tensorflow:loss = 0.00074938475, step = 23601 (0.346 sec)
# INFO:tensorflow:global_step/sec: 296.237
# INFO:tensorflow:loss = 0.00026852463, step = 23701 (0.338 sec)
# INFO:tensorflow:global_step/sec: 285.622
# INFO:tensorflow:loss = 0.0014435563, step = 23801 (0.350 sec)
# INFO:tensorflow:global_step/sec: 292.428
# INFO:tensorflow:loss = 0.0011531893, step = 23901 (0.342 sec)
# INFO:tensorflow:global_step/sec: 300.529
# INFO:tensorflow:loss = 0.0012715489, step = 24001 (0.333 sec)
# INFO:tensorflow:global_step/sec: 295.252
# INFO:tensorflow:loss = 0.0005405474, step = 24101 (0.342 sec)
# INFO:tensorflow:global_step/sec: 292.462
# INFO:tensorflow:loss = 0.00225385, step = 24201 (0.338 sec)
# INFO:tensorflow:global_step/sec: 307.044
# INFO:tensorflow:loss = 0.000121644334, step = 24301 (0.326 sec)
# INFO:tensorflow:global_step/sec: 315.205
# INFO:tensorflow:loss = 0.002113765, step = 24401 (0.317 sec)
# INFO:tensorflow:global_step/sec: 314.513
# INFO:tensorflow:loss = 0.0008776918, step = 24501 (0.318 sec)
# INFO:tensorflow:global_step/sec: 313.073
# INFO:tensorflow:loss = 0.00035939075, step = 24601 (0.319 sec)
# INFO:tensorflow:global_step/sec: 298.936
# INFO:tensorflow:loss = 0.0005216072, step = 24701 (0.334 sec)
# INFO:tensorflow:global_step/sec: 282.721
# INFO:tensorflow:loss = 0.0012975181, step = 24801 (0.354 sec)
# INFO:tensorflow:global_step/sec: 292.889
# INFO:tensorflow:loss = 0.0013502991, step = 24901 (0.342 sec)
# INFO:tensorflow:global_step/sec: 283.637
# INFO:tensorflow:loss = 0.00030805275, step = 25001 (0.353 sec)
# INFO:tensorflow:global_step/sec: 313.34
# INFO:tensorflow:loss = 0.0007631263, step = 25101 (0.319 sec)
# INFO:tensorflow:global_step/sec: 311.603
# INFO:tensorflow:loss = 0.0018998438, step = 25201 (0.321 sec)
# INFO:tensorflow:global_step/sec: 306.741
# INFO:tensorflow:loss = 7.639955e-05, step = 25301 (0.326 sec)
# INFO:tensorflow:global_step/sec: 314.108
# INFO:tensorflow:loss = 0.0006683834, step = 25401 (0.318 sec)
# INFO:tensorflow:global_step/sec: 308.541
# INFO:tensorflow:loss = 0.00093682384, step = 25501 (0.324 sec)
# INFO:tensorflow:global_step/sec: 314.214
# INFO:tensorflow:loss = 0.001147533, step = 25601 (0.318 sec)
# INFO:tensorflow:global_step/sec: 308.239
# INFO:tensorflow:loss = 0.0006657222, step = 25701 (0.325 sec)
# INFO:tensorflow:global_step/sec: 319.883
# INFO:tensorflow:loss = 0.0011927338, step = 25801 (0.314 sec)
# INFO:tensorflow:global_step/sec: 308.923
# INFO:tensorflow:loss = 0.0015841662, step = 25901 (0.323 sec)
# INFO:tensorflow:global_step/sec: 308.94
# INFO:tensorflow:loss = 7.614875e-05, step = 26001 (0.324 sec)
# INFO:tensorflow:global_step/sec: 325.719
# INFO:tensorflow:loss = 0.0009053111, step = 26101 (0.307 sec)
# INFO:tensorflow:global_step/sec: 319.304
# INFO:tensorflow:loss = 0.00076690764, step = 26201 (0.313 sec)
# INFO:tensorflow:global_step/sec: 313.397
# INFO:tensorflow:loss = 0.0008719411, step = 26301 (0.319 sec)
# INFO:tensorflow:global_step/sec: 317.558
# INFO:tensorflow:loss = 0.0013913005, step = 26401 (0.315 sec)
# INFO:tensorflow:global_step/sec: 316.002
# INFO:tensorflow:loss = 0.0011720075, step = 26501 (0.316 sec)
# INFO:tensorflow:global_step/sec: 310.023
# INFO:tensorflow:loss = 0.0003570809, step = 26601 (0.323 sec)
# INFO:tensorflow:global_step/sec: 319.025
# INFO:tensorflow:loss = 5.4657212e-05, step = 26701 (0.314 sec)
# INFO:tensorflow:global_step/sec: 313.831
# INFO:tensorflow:loss = 0.0005371068, step = 26801 (0.318 sec)
# INFO:tensorflow:global_step/sec: 315.996
# INFO:tensorflow:loss = 0.00086502207, step = 26901 (0.316 sec)
# INFO:tensorflow:global_step/sec: 322.469
# INFO:tensorflow:loss = 0.00085236324, step = 27001 (0.310 sec)
# INFO:tensorflow:global_step/sec: 315.537
# INFO:tensorflow:loss = 0.0004112166, step = 27101 (0.317 sec)
# INFO:tensorflow:global_step/sec: 320.984
# INFO:tensorflow:loss = 0.00033003162, step = 27201 (0.311 sec)
# INFO:tensorflow:global_step/sec: 309.24
# INFO:tensorflow:loss = 0.0009347762, step = 27301 (0.324 sec)
# INFO:tensorflow:global_step/sec: 307.677
# INFO:tensorflow:loss = 9.702885e-05, step = 27401 (0.325 sec)
# INFO:tensorflow:global_step/sec: 309.853
# INFO:tensorflow:loss = 0.0014474434, step = 27501 (0.323 sec)
# INFO:tensorflow:global_step/sec: 307.776
# INFO:tensorflow:loss = 0.00072644633, step = 27601 (0.325 sec)
# INFO:tensorflow:global_step/sec: 308.747
# INFO:tensorflow:loss = 0.00031730867, step = 27701 (0.324 sec)
# INFO:tensorflow:global_step/sec: 311.537
# INFO:tensorflow:loss = 0.00026854943, step = 27801 (0.321 sec)
# INFO:tensorflow:global_step/sec: 315.965
# INFO:tensorflow:loss = 0.00057551445, step = 27901 (0.317 sec)
# INFO:tensorflow:global_step/sec: 305.017
# INFO:tensorflow:loss = 0.0010824426, step = 28001 (0.328 sec)
# INFO:tensorflow:global_step/sec: 306.537
# INFO:tensorflow:loss = 0.00058105955, step = 28101 (0.327 sec)
# INFO:tensorflow:global_step/sec: 313.673
# INFO:tensorflow:loss = 0.001494826, step = 28201 (0.318 sec)
# INFO:tensorflow:global_step/sec: 306.844
# INFO:tensorflow:loss = 0.00077025575, step = 28301 (0.326 sec)
# INFO:tensorflow:global_step/sec: 310.599
# INFO:tensorflow:loss = 0.00073158456, step = 28401 (0.322 sec)
# INFO:tensorflow:global_step/sec: 305.997
# INFO:tensorflow:loss = 0.00019929308, step = 28501 (0.327 sec)
# INFO:tensorflow:global_step/sec: 310.622
# INFO:tensorflow:loss = 0.00039712348, step = 28601 (0.322 sec)
# INFO:tensorflow:global_step/sec: 309.996
# INFO:tensorflow:loss = 0.0006938218, step = 28701 (0.322 sec)
# INFO:tensorflow:global_step/sec: 308.44
# INFO:tensorflow:loss = 0.0011052645, step = 28801 (0.324 sec)
# INFO:tensorflow:global_step/sec: 312.654
# INFO:tensorflow:loss = 0.00019511173, step = 28901 (0.320 sec)
# INFO:tensorflow:global_step/sec: 309.252
# INFO:tensorflow:loss = 0.001962383, step = 29001 (0.323 sec)
# INFO:tensorflow:global_step/sec: 312.832
# INFO:tensorflow:loss = 0.0008439263, step = 29101 (0.320 sec)
# INFO:tensorflow:global_step/sec: 313.893
# INFO:tensorflow:loss = 0.0013379279, step = 29201 (0.319 sec)
# INFO:tensorflow:global_step/sec: 319.775
# INFO:tensorflow:loss = 0.0015603198, step = 29301 (0.313 sec)
# INFO:tensorflow:global_step/sec: 312.563
# INFO:tensorflow:loss = 0.001495288, step = 29401 (0.320 sec)
# INFO:tensorflow:global_step/sec: 306.156
# INFO:tensorflow:loss = 0.0013261959, step = 29501 (0.327 sec)
# INFO:tensorflow:global_step/sec: 309.641
# INFO:tensorflow:loss = 0.00018369245, step = 29601 (0.323 sec)
# INFO:tensorflow:global_step/sec: 302.444
# INFO:tensorflow:loss = 0.00030377164, step = 29701 (0.331 sec)
# INFO:tensorflow:global_step/sec: 308.889
# INFO:tensorflow:loss = 0.0005793918, step = 29801 (0.324 sec)
# INFO:tensorflow:global_step/sec: 304.822
# INFO:tensorflow:loss = 0.0014531676, step = 29901 (0.328 sec)
# INFO:tensorflow:global_step/sec: 313.805
# INFO:tensorflow:loss = 0.000102629325, step = 30001 (0.319 sec)
# INFO:tensorflow:global_step/sec: 310.643
# INFO:tensorflow:loss = 0.0008462737, step = 30101 (0.322 sec)
# INFO:tensorflow:global_step/sec: 306.55
# INFO:tensorflow:loss = 0.00032873594, step = 30201 (0.326 sec)
# INFO:tensorflow:global_step/sec: 307.814
# INFO:tensorflow:loss = 0.001048071, step = 30301 (0.325 sec)
# INFO:tensorflow:global_step/sec: 309.875
# INFO:tensorflow:loss = 0.0014858026, step = 30401 (0.322 sec)
# INFO:tensorflow:global_step/sec: 310.943
# INFO:tensorflow:loss = 0.00067418744, step = 30501 (0.322 sec)
# INFO:tensorflow:global_step/sec: 250.142
# INFO:tensorflow:loss = 0.00094798533, step = 30601 (0.400 sec)
# INFO:tensorflow:global_step/sec: 305.758
# INFO:tensorflow:loss = 0.00072131277, step = 30701 (0.327 sec)
# INFO:tensorflow:global_step/sec: 306.937
# INFO:tensorflow:loss = 0.000988826, step = 30801 (0.326 sec)
# INFO:tensorflow:global_step/sec: 305.65
# INFO:tensorflow:loss = 0.00093700417, step = 30901 (0.327 sec)
# INFO:tensorflow:global_step/sec: 313.282
# INFO:tensorflow:loss = 0.000874456, step = 31001 (0.319 sec)
# INFO:tensorflow:global_step/sec: 306.157
# INFO:tensorflow:loss = 0.0009253605, step = 31101 (0.327 sec)
# INFO:tensorflow:global_step/sec: 307.72
# INFO:tensorflow:loss = 0.00029182178, step = 31201 (0.325 sec)
# INFO:tensorflow:global_step/sec: 313.533
# INFO:tensorflow:loss = 0.00044317468, step = 31301 (0.319 sec)
# INFO:tensorflow:global_step/sec: 308.508
# INFO:tensorflow:loss = 0.0008065422, step = 31401 (0.324 sec)
# INFO:tensorflow:global_step/sec: 300.396
# INFO:tensorflow:loss = 0.00024275045, step = 31501 (0.333 sec)
# INFO:tensorflow:global_step/sec: 314.384
# INFO:tensorflow:loss = 0.00019925728, step = 31601 (0.318 sec)
# INFO:tensorflow:global_step/sec: 314.355
# INFO:tensorflow:loss = 0.00042737435, step = 31701 (0.318 sec)
# INFO:tensorflow:global_step/sec: 306.054
# INFO:tensorflow:loss = 0.0002842592, step = 31801 (0.327 sec)
# INFO:tensorflow:global_step/sec: 305.895
# INFO:tensorflow:loss = 0.0004509533, step = 31901 (0.327 sec)
# INFO:tensorflow:global_step/sec: 310.717
# INFO:tensorflow:loss = 0.0003155615, step = 32001 (0.322 sec)
# INFO:tensorflow:global_step/sec: 307.205
# INFO:tensorflow:loss = 0.0005702587, step = 32101 (0.326 sec)
# INFO:tensorflow:global_step/sec: 310.715
# INFO:tensorflow:loss = 0.0015450015, step = 32201 (0.322 sec)
# INFO:tensorflow:global_step/sec: 312.299
# INFO:tensorflow:loss = 0.00050654524, step = 32301 (0.320 sec)
# INFO:tensorflow:global_step/sec: 309.167
# INFO:tensorflow:loss = 0.00010819726, step = 32401 (0.324 sec)
# INFO:tensorflow:global_step/sec: 307.059
# INFO:tensorflow:loss = 0.00052572764, step = 32501 (0.326 sec)
# INFO:tensorflow:global_step/sec: 302.925
# INFO:tensorflow:loss = 0.00011118672, step = 32601 (0.330 sec)
# INFO:tensorflow:global_step/sec: 309.833
# INFO:tensorflow:loss = 0.0010664613, step = 32701 (0.323 sec)
# INFO:tensorflow:global_step/sec: 305.775
# INFO:tensorflow:loss = 0.0012585926, step = 32801 (0.327 sec)
# INFO:tensorflow:global_step/sec: 310.454
# INFO:tensorflow:loss = 0.0004315094, step = 32901 (0.322 sec)
# INFO:tensorflow:global_step/sec: 307.832
# INFO:tensorflow:loss = 0.00068739295, step = 33001 (0.325 sec)
# INFO:tensorflow:global_step/sec: 304.473
# INFO:tensorflow:loss = 0.0017354221, step = 33101 (0.328 sec)
# INFO:tensorflow:global_step/sec: 308.121
# INFO:tensorflow:loss = 0.00084215234, step = 33201 (0.324 sec)
# INFO:tensorflow:global_step/sec: 303.371
# INFO:tensorflow:loss = 0.00023161076, step = 33301 (0.330 sec)
# INFO:tensorflow:global_step/sec: 307.902
# INFO:tensorflow:loss = 0.0012861075, step = 33401 (0.325 sec)
# INFO:tensorflow:global_step/sec: 304.665
# INFO:tensorflow:loss = 0.00027212556, step = 33501 (0.328 sec)
# INFO:tensorflow:global_step/sec: 309.394
# INFO:tensorflow:loss = 0.0006272994, step = 33601 (0.323 sec)
# INFO:tensorflow:global_step/sec: 311.564
# INFO:tensorflow:loss = 0.0009675624, step = 33701 (0.321 sec)
# INFO:tensorflow:global_step/sec: 302.46
# INFO:tensorflow:loss = 0.0011607357, step = 33801 (0.331 sec)
# INFO:tensorflow:global_step/sec: 308.829
# INFO:tensorflow:loss = 0.001781042, step = 33901 (0.324 sec)
# INFO:tensorflow:global_step/sec: 315.098
# INFO:tensorflow:loss = 0.000859264, step = 34001 (0.317 sec)
# INFO:tensorflow:global_step/sec: 305.859
# INFO:tensorflow:loss = 0.00049984193, step = 34101 (0.327 sec)
# INFO:tensorflow:global_step/sec: 303.592
# INFO:tensorflow:loss = 0.0013903561, step = 34201 (0.329 sec)
# INFO:tensorflow:global_step/sec: 303.632
# INFO:tensorflow:loss = 0.00017352056, step = 34301 (0.330 sec)
# INFO:tensorflow:global_step/sec: 309.019
# INFO:tensorflow:loss = 0.0005864169, step = 34401 (0.323 sec)
# INFO:tensorflow:global_step/sec: 305.121
# INFO:tensorflow:loss = 0.00062983565, step = 34501 (0.328 sec)
# INFO:tensorflow:global_step/sec: 310.787
# INFO:tensorflow:loss = 0.0005378149, step = 34601 (0.322 sec)
# INFO:tensorflow:global_step/sec: 302.938
# INFO:tensorflow:loss = 0.0012963918, step = 34701 (0.330 sec)
# INFO:tensorflow:global_step/sec: 311.307
# INFO:tensorflow:loss = 0.00054115674, step = 34801 (0.321 sec)
# INFO:tensorflow:global_step/sec: 296.518
# INFO:tensorflow:loss = 0.00061186566, step = 34901 (0.337 sec)
# INFO:tensorflow:global_step/sec: 303.716
# INFO:tensorflow:loss = 0.00045716617, step = 35001 (0.329 sec)
# INFO:tensorflow:global_step/sec: 308.524
# INFO:tensorflow:loss = 0.00077852537, step = 35101 (0.324 sec)
# INFO:tensorflow:global_step/sec: 301.978
# INFO:tensorflow:loss = 0.00035512313, step = 35201 (0.331 sec)
# INFO:tensorflow:global_step/sec: 311.692
# INFO:tensorflow:loss = 0.00018169491, step = 35301 (0.321 sec)
# INFO:tensorflow:global_step/sec: 304.049
# INFO:tensorflow:loss = 0.0010593754, step = 35401 (0.329 sec)
# INFO:tensorflow:global_step/sec: 309.683
# INFO:tensorflow:loss = 0.00013453029, step = 35501 (0.323 sec)
# INFO:tensorflow:global_step/sec: 320.279
# INFO:tensorflow:loss = 0.00014518229, step = 35601 (0.312 sec)
# INFO:tensorflow:global_step/sec: 308.11
# INFO:tensorflow:loss = 0.0009905142, step = 35701 (0.324 sec)
# INFO:tensorflow:global_step/sec: 312.046
# INFO:tensorflow:loss = 0.00050275377, step = 35801 (0.321 sec)
# INFO:tensorflow:global_step/sec: 304.679
# INFO:tensorflow:loss = 0.0006155347, step = 35901 (0.328 sec)
# INFO:tensorflow:global_step/sec: 314.213
# INFO:tensorflow:loss = 0.0004306907, step = 36001 (0.318 sec)
# INFO:tensorflow:global_step/sec: 303.107
# INFO:tensorflow:loss = 0.0010139751, step = 36101 (0.330 sec)
# INFO:tensorflow:global_step/sec: 305.073
# INFO:tensorflow:loss = 0.00064610207, step = 36201 (0.328 sec)
# INFO:tensorflow:global_step/sec: 309.423
# INFO:tensorflow:loss = 0.00051618734, step = 36301 (0.323 sec)
# INFO:tensorflow:global_step/sec: 303.532
# INFO:tensorflow:loss = 0.00060389476, step = 36401 (0.329 sec)
# INFO:tensorflow:global_step/sec: 315.725
# INFO:tensorflow:loss = 0.00021290706, step = 36501 (0.317 sec)
# INFO:tensorflow:global_step/sec: 305.016
# INFO:tensorflow:loss = 0.0002317578, step = 36601 (0.328 sec)
# INFO:tensorflow:global_step/sec: 310.762
# INFO:tensorflow:loss = 0.00033519036, step = 36701 (0.322 sec)
# INFO:tensorflow:global_step/sec: 311.887
# INFO:tensorflow:loss = 0.0006506221, step = 36801 (0.321 sec)
# INFO:tensorflow:global_step/sec: 307.955
# INFO:tensorflow:loss = 0.00072300044, step = 36901 (0.325 sec)
# INFO:tensorflow:global_step/sec: 310.643
# INFO:tensorflow:loss = 0.0006022467, step = 37001 (0.322 sec)
# INFO:tensorflow:global_step/sec: 304.464
# INFO:tensorflow:loss = 0.000249216, step = 37101 (0.328 sec)
# INFO:tensorflow:global_step/sec: 309.676
# INFO:tensorflow:loss = 0.00022897162, step = 37201 (0.323 sec)
# INFO:tensorflow:global_step/sec: 302.955
# INFO:tensorflow:loss = 0.0005957739, step = 37301 (0.330 sec)
# INFO:tensorflow:global_step/sec: 305.749
# INFO:tensorflow:loss = 0.00039969682, step = 37401 (0.327 sec)
# INFO:tensorflow:global_step/sec: 312.352
# INFO:tensorflow:loss = 0.00019449933, step = 37501 (0.320 sec)
# INFO:tensorflow:global_step/sec: 312.412
# INFO:tensorflow:loss = 0.00018291408, step = 37601 (0.320 sec)
# INFO:tensorflow:global_step/sec: 313.125
# INFO:tensorflow:loss = 6.0790306e-05, step = 37701 (0.319 sec)
# INFO:tensorflow:global_step/sec: 308.524
# INFO:tensorflow:loss = 0.0003086013, step = 37801 (0.324 sec)
# INFO:tensorflow:global_step/sec: 306.759
# INFO:tensorflow:loss = 0.0010888482, step = 37901 (0.326 sec)
# INFO:tensorflow:global_step/sec: 304.913
# INFO:tensorflow:loss = 0.00022770562, step = 38001 (0.328 sec)
# INFO:tensorflow:global_step/sec: 308.547
# INFO:tensorflow:loss = 0.0011822297, step = 38101 (0.324 sec)
# INFO:tensorflow:global_step/sec: 309.844
# INFO:tensorflow:loss = 0.00061454467, step = 38201 (0.323 sec)
# INFO:tensorflow:global_step/sec: 304.278
# INFO:tensorflow:loss = 0.00025094085, step = 38301 (0.329 sec)
# INFO:tensorflow:global_step/sec: 311.747
# INFO:tensorflow:loss = 0.00013526661, step = 38401 (0.321 sec)
# INFO:tensorflow:global_step/sec: 305.926
# INFO:tensorflow:loss = 0.0006654819, step = 38501 (0.327 sec)
# INFO:tensorflow:global_step/sec: 308.967
# INFO:tensorflow:loss = 0.0004853789, step = 38601 (0.323 sec)
# INFO:tensorflow:global_step/sec: 312.237
# INFO:tensorflow:loss = 0.00041229356, step = 38701 (0.320 sec)
# INFO:tensorflow:global_step/sec: 305.624
# INFO:tensorflow:loss = 0.00025498844, step = 38801 (0.327 sec)
# INFO:tensorflow:global_step/sec: 311.704
# INFO:tensorflow:loss = 0.0012883587, step = 38901 (0.321 sec)
# INFO:tensorflow:global_step/sec: 304.051
# INFO:tensorflow:loss = 0.00010498734, step = 39001 (0.329 sec)
# INFO:tensorflow:global_step/sec: 309.938
# INFO:tensorflow:loss = 0.0006219527, step = 39101 (0.323 sec)
# INFO:tensorflow:global_step/sec: 304.049
# INFO:tensorflow:loss = 0.00023261146, step = 39201 (0.329 sec)
# INFO:tensorflow:global_step/sec: 309.305
# INFO:tensorflow:loss = 0.00030755508, step = 39301 (0.323 sec)
# INFO:tensorflow:global_step/sec: 309.31
# INFO:tensorflow:loss = 0.00066522404, step = 39401 (0.323 sec)
# INFO:tensorflow:global_step/sec: 305.033
# INFO:tensorflow:loss = 0.00011748233, step = 39501 (0.328 sec)
# INFO:tensorflow:global_step/sec: 308.151
# INFO:tensorflow:loss = 0.00070022134, step = 39601 (0.324 sec)
# INFO:tensorflow:global_step/sec: 306.068
# INFO:tensorflow:loss = 6.663389e-05, step = 39701 (0.327 sec)
# INFO:tensorflow:global_step/sec: 310.17
# INFO:tensorflow:loss = 0.0018119463, step = 39801 (0.322 sec)
# INFO:tensorflow:global_step/sec: 307.735
# INFO:tensorflow:loss = 0.001219137, step = 39901 (0.325 sec)
# INFO:tensorflow:Saving checkpoints for 40000 into /var/folders/6g/q2scz4c92pdf777kd5gg_kpm0000gn/T/tmpd_umpgk2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0004535416.
# DNNClassifier(params={'head': <tensorflow.contrib.learn.python.learn.estimators.head._MultiClassHead object at 0x12b82e860>, 'hidden_units': [300, 100], 'feature_columns': (_RealValuedColumn(column_name='', dimension=784, default_value=None, dtype=tf.float32, normalizer=None),), 'optimizer': None, 'activation_fn': <function relu at 0x126c23d90>, 'dropout': None, 'gradient_clip_norm': None, 'embedding_lr_multipliers': None, 'input_layer_min_slice_size': None})

# %%
from sklearn.metrics import accuracy_score

y_pred = list(dnn_clf.predict(X_test))
accuracy_score(y_test, y_pred)
# Out:
# WARNING:tensorflow:From /Users/liufang/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:553: calling DNNClassifier.predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_classes, or set `outputs` argument.
# WARNING:tensorflow:From /Users/liufang/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:463: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/6g/q2scz4c92pdf777kd5gg_kpm0000gn/T/tmpd_umpgk2/model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 0.9832

# %%
dnn_clf
# Out:
# DNNClassifier(params={'head': <tensorflow.contrib.learn.python.learn.estimators.head._MultiClassHead object at 0x12b82e860>, 'hidden_units': [300, 100], 'feature_columns': (_RealValuedColumn(column_name='', dimension=784, default_value=None, dtype=tf.float32, normalizer=None),), 'optimizer': None, 'activation_fn': <function relu at 0x126c23d90>, 'dropout': None, 'gradient_clip_norm': None, 'embedding_lr_multipliers': None, 'input_layer_min_slice_size': None})

# %%
dnn_clf.evaluate(X_test, y_test)
# Out:
# WARNING:tensorflow:From <ipython-input-11-8442dafa3532>:1: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-11-8442dafa3532>:1: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# INFO:tensorflow:Starting evaluation at 2019-02-22-15:54:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/6g/q2scz4c92pdf777kd5gg_kpm0000gn/T/tmpd_umpgk2/model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-22-15:54:37
# INFO:tensorflow:Saving dict for global step 40000: accuracy = 0.9832, global_step = 40000, loss = 0.06935729
# {'accuracy': 0.9832, 'global_step': 40000, 'loss': 0.06935729}

# %% [markdown]
# # DNN

# %% [markdown]
# ### Construction Phase

# %%
n_inputs = 28*28
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %%
X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

# %%
def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs)
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        W = tf.Variable(init, name="weights")
        b = tf.Variable(tf.zeros([n_neurons]), name="biases")
        z = tf.matmul(X, W) + b
        if activation == "relu":
            return tf.nn.relu(z)
        else:
            return z

# %%
with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, "hidden1", activation="relu")
    hidden2 = neuron_layer(hidden1, n_hidden2, "hidden2", activation="relu")
    logits = neuron_layer(hidden2, n_outputs, "outputs")

# %%
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(
        labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)  # logits == outputs
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %% [markdown]
# ### Execution Phase

# %%
from tensorflow.examples.tutorials.mnist import input_data

# %%
n_epochs = 40
batch_size = 50

# %%
def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X) // batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches):
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

# %% [markdown]
# **yield** (generator), return

# %%
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_batch = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_val = accuracy.eval(feed_dict={X: X_valid, y: y_valid})
        print(epoch, "Batch arruracy:", acc_batch, "Val accuracy:", acc_val)
    
    save_path = saver.save(sess, "./my_model_final.ckpt")
# Out:
# 0 Batch arruracy: 0.9 Val accuracy: 0.9238
# 1 Batch arruracy: 0.84 Val accuracy: 0.9382
# 2 Batch arruracy: 0.96 Val accuracy: 0.9458
# 3 Batch arruracy: 0.96 Val accuracy: 0.9502
# 4 Batch arruracy: 0.92 Val accuracy: 0.9542
# 5 Batch arruracy: 0.94 Val accuracy: 0.9562
# 6 Batch arruracy: 0.92 Val accuracy: 0.9586
# 7 Batch arruracy: 0.96 Val accuracy: 0.9628
# 8 Batch arruracy: 1.0 Val accuracy: 0.964
# 9 Batch arruracy: 0.94 Val accuracy: 0.965
# 10 Batch arruracy: 0.94 Val accuracy: 0.9668
# 11 Batch arruracy: 0.96 Val accuracy: 0.9692
# 12 Batch arruracy: 0.98 Val accuracy: 0.9698
# 13 Batch arruracy: 0.96 Val accuracy: 0.9702
# 14 Batch arruracy: 0.98 Val accuracy: 0.97
# 15 Batch arruracy: 0.98 Val accuracy: 0.9698
# 16 Batch arruracy: 0.98 Val accuracy: 0.9706
# 17 Batch arruracy: 1.0 Val accuracy: 0.971
# 18 Batch arruracy: 0.98 Val accuracy: 0.9716
# 19 Batch arruracy: 0.94 Val accuracy: 0.9726
# 20 Batch arruracy: 1.0 Val accuracy: 0.972
# 21 Batch arruracy: 1.0 Val accuracy: 0.9732
# 22 Batch arruracy: 0.98 Val accuracy: 0.9736
# 23 Batch arruracy: 1.0 Val accuracy: 0.9742
# 24 Batch arruracy: 1.0 Val accuracy: 0.975
# 25 Batch arruracy: 0.98 Val accuracy: 0.975
# 26 Batch arruracy: 1.0 Val accuracy: 0.9736
# 27 Batch arruracy: 1.0 Val accuracy: 0.975
# 28 Batch arruracy: 1.0 Val accuracy: 0.9748
# 29 Batch arruracy: 1.0 Val accuracy: 0.974
# 30 Batch arruracy: 1.0 Val accuracy: 0.9758
# 31 Batch arruracy: 1.0 Val accuracy: 0.9774
# 32 Batch arruracy: 1.0 Val accuracy: 0.9746
# 33 Batch arruracy: 1.0 Val accuracy: 0.9758
# 34 Batch arruracy: 1.0 Val accuracy: 0.978
# 35 Batch arruracy: 1.0 Val accuracy: 0.9784
# 36 Batch arruracy: 1.0 Val accuracy: 0.9782
# 37 Batch arruracy: 0.98 Val accuracy: 0.9774
# 38 Batch arruracy: 1.0 Val accuracy: 0.978
# 39 Batch arruracy: 1.0 Val accuracy: 0.9772

# %% [markdown]
# ### Using the Neural Network

# %%
# with tf.Session() as sess:
#     saver.restore(sess, "./my_model_final.ckpt")
#     X_new_scaled = X_test[:20]
#     Z = logits.eval(feed_dict={X: X_new_scaled})
#     y_pred = np.argmax(Z, axis=1)

# %%
# y_pred

# %%
file_writer = tf.summary.FileWriter("./tf_logs/mnist1/", tf.get_default_graph())

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                          'two'],
                  'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                  'baz': [1, 2, 3, 4, 5, 6],
                  'zoo': ['x', 'y', 'z', 'q', 'w', 't']})

# %%
df
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
df.pivot(index="foo", columns="bar")
# Out:
#     baz       zoo
# bar   A  B  C   A  B  C
# foo
# one   1  2  3   x  y  z
# two   4  5  6   q  w  t

# %%
s = pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
datas = pd.date_range('20130101', periods=6)

# %%
datas
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=datas, columns=list('ABCD'))

# %%
df2 = pd.DataFrame({ 'A': 1,
                     'B': pd.Timestamp('20130102'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3] * 4, dtype='int32'),
                    'E': pd.Categorical(["test", "train", "test", "train"]),
                    'F': 'foo'
                   })

# %%
df2
# Out:
#    A          B    C  D      E    F
# 0  1 2013-01-02  1.0  3   test  foo
# 1  1 2013-01-02  1.0  3  train  foo
# 2  1 2013-01-02  1.0  3   test  foo
# 3  1 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.307306  1.144141  1.373960  0.723557
# 2013-01-02 -0.137733  2.751430  1.864549 -0.056077
# 2013-01-03 -0.756323  1.746032 -1.263350 -0.516354
# 2013-01-04  1.978866  0.156216 -1.804749  0.113764
# 2013-01-05  0.269351  1.321942  0.714950  1.085879

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.307306  1.144141  1.373960  0.723557
# 2013-01-02 -0.137733  2.751430  1.864549 -0.056077
# 2013-01-03 -0.756323  1.746032 -1.263350 -0.516354
# 2013-01-04  1.978866  0.156216 -1.804749  0.113764
# 2013-01-05  0.269351  1.321942  0.714950  1.085879
# 2013-01-06 -0.538552 -0.460371  0.411290 -1.640347

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  1.978866  0.156216 -1.804749  0.113764
# 2013-01-05  0.269351  1.321942  0.714950  1.085879
# 2013-01-06 -0.538552 -0.460371  0.411290 -1.640347

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.30730578,  1.14414106,  1.37396011,  0.72355687],
#        [-0.13773256,  2.7514301 ,  1.86454878, -0.05607728],
#        [-0.75632272,  1.74603161, -1.2633504 , -0.51635358],
#        [ 1.97886633,  0.15621622, -1.8047494 ,  0.11376361],
#        [ 0.2693507 ,  1.32194169,  0.71494969,  1.08587893],
#        [-0.5385521 , -0.46037087,  0.4112898 , -1.64034674]])

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.307306  1.144141  1.373960  0.723557
# 2013-01-02 -0.137733  2.751430  1.864549 -0.056077
# 2013-01-03 -0.756323  1.746032 -1.263350 -0.516354
# 2013-01-04  1.978866  0.156216 -1.804749  0.113764
# 2013-01-05  0.269351  1.321942  0.714950  1.085879
# 2013-01-06 -0.538552 -0.460371  0.411290 -1.640347

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.187153  1.109898  0.216108 -0.048263
# std    0.975067  1.141988  1.457229  0.965623
# min   -0.756323 -0.460371 -1.804749 -1.640347
# 25%   -0.438347  0.403197 -0.844690 -0.401285
# 50%    0.065809  1.233041  0.563120  0.028843
# 75%    0.297817  1.640009  1.209208  0.571109
# max    1.978866  2.751430  1.864549  1.085879

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.307306   -0.137733   -0.756323    1.978866    0.269351   -0.538552
# B    1.144141    2.751430    1.746032    0.156216    1.321942   -0.460371
# C    1.373960    1.864549   -1.263350   -1.804749    0.714950    0.411290
# D    0.723557   -0.056077   -0.516354    0.113764    1.085879   -1.640347

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.723557  1.373960  1.144141  0.307306
# 2013-01-02 -0.056077  1.864549  2.751430 -0.137733
# 2013-01-03 -0.516354 -1.263350  1.746032 -0.756323
# 2013-01-04  0.113764 -1.804749  0.156216  1.978866
# 2013-01-05  1.085879  0.714950  1.321942  0.269351
# 2013-01-06 -1.640347  0.411290 -0.460371 -0.538552

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-06 -0.538552 -0.460371  0.411290 -1.640347
# 2013-01-04  1.978866  0.156216 -1.804749  0.113764
# 2013-01-01  0.307306  1.144141  1.373960  0.723557
# 2013-01-05  0.269351  1.321942  0.714950  1.085879
# 2013-01-03 -0.756323  1.746032 -1.263350 -0.516354
# 2013-01-02 -0.137733  2.751430  1.864549 -0.056077

# %%
df['A']
# Out:
# 2013-01-01    0.307306
# 2013-01-02   -0.137733
# 2013-01-03   -0.756323
# 2013-01-04    1.978866
# 2013-01-05    0.269351
# 2013-01-06   -0.538552
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.307306  1.144141  1.373960  0.723557
# 2013-01-02 -0.137733  2.751430  1.864549 -0.056077
# 2013-01-03 -0.756323  1.746032 -1.263350 -0.516354

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02 -0.137733  2.751430  1.864549 -0.056077
# 2013-01-03 -0.756323  1.746032 -1.263350 -0.516354
# 2013-01-04  1.978866  0.156216 -1.804749  0.113764

# %%
df.loc[datas[0]]
# Out:
# A    0.307306
# B    1.144141
# C    1.373960
# D    0.723557
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
datas
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.loc['20130102':'20130104', ['A', 'B']]
# Out:
#                    A         B
# 2013-01-02 -0.137733  2.751430
# 2013-01-03 -0.756323  1.746032
# 2013-01-04  1.978866  0.156216

# %%
datas[0]
# Out:
# Timestamp('2013-01-01 00:00:00', freq='D')

# %%
df.loc[datas[0], 'A']
# Out:
# 0.30730577563665346

# %%
df.at[datas[0], 'A']
# Out:
# 0.30730577563665346

# %%
df.iloc[0]
# Out:
# A    0.307306
# B    1.144141
# C    1.373960
# D    0.723557
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.307306  1.144141  1.373960  0.723557
# 2013-01-02 -0.137733  2.751430  1.864549 -0.056077
# 2013-01-03 -0.756323  1.746032 -1.263350 -0.516354
# 2013-01-04  1.978866  0.156216 -1.804749  0.113764
# 2013-01-05  0.269351  1.321942  0.714950  1.085879
# 2013-01-06 -0.538552 -0.460371  0.411290 -1.640347

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  1.978866  0.156216
# 2013-01-05  0.269351  1.321942

# %%
df.iloc[[1,2,4], [0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.137733  1.864549
# 2013-01-03 -0.756323 -1.263350
# 2013-01-05  0.269351  0.714950

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.137733  2.751430  1.864549 -0.056077
# 2013-01-03 -0.756323  1.746032 -1.263350 -0.516354

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  1.144141  1.373960
# 2013-01-02  2.751430  1.864549
# 2013-01-03  1.746032 -1.263350
# 2013-01-04  0.156216 -1.804749
# 2013-01-05  1.321942  0.714950
# 2013-01-06 -0.460371  0.411290

# %%
df.iloc[1,1]
# Out:
# 2.7514300977658781

# %%
df.iat[1,1]
# Out:
# 2.7514300977658781

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.307306  1.144141  1.373960  0.723557
# 2013-01-02 -0.137733  2.751430  1.864549 -0.056077
# 2013-01-03 -0.756323  1.746032 -1.263350 -0.516354
# 2013-01-04  1.978866  0.156216 -1.804749  0.113764
# 2013-01-05  0.269351  1.321942  0.714950  1.085879
# 2013-01-06 -0.538552 -0.460371  0.411290 -1.640347

# %%
df[df.A>0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.307306  1.144141  1.373960  0.723557
# 2013-01-04  1.978866  0.156216 -1.804749  0.113764
# 2013-01-05  0.269351  1.321942  0.714950  1.085879

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.307306  1.144141  1.373960  0.723557
# 2013-01-02       NaN  2.751430  1.864549       NaN
# 2013-01-03       NaN  1.746032       NaN       NaN
# 2013-01-04  1.978866  0.156216       NaN  0.113764
# 2013-01-05  0.269351  1.321942  0.714950  1.085879
# 2013-01-06       NaN       NaN  0.411290       NaN

# %%
df2 = df.copy()

# %%
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.307306  1.144141  1.373960  0.723557    one
# 2013-01-02 -0.137733  2.751430  1.864549 -0.056077    one
# 2013-01-03 -0.756323  1.746032 -1.263350 -0.516354    two
# 2013-01-04  1.978866  0.156216 -1.804749  0.113764  three
# 2013-01-05  0.269351  1.321942  0.714950  1.085879   four
# 2013-01-06 -0.538552 -0.460371  0.411290 -1.640347  three

# %%
df[df2['E'].isin(['two', 'four'])]
# Out:
#                    A         B        C         D
# 2013-01-03 -0.756323  1.746032 -1.26335 -0.516354
# 2013-01-05  0.269351  1.321942  0.71495  1.085879

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102', periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.307306  1.144141  1.373960  0.723557  NaN
# 2013-01-02 -0.137733  2.751430  1.864549 -0.056077  1.0
# 2013-01-03 -0.756323  1.746032 -1.263350 -0.516354  2.0
# 2013-01-04  1.978866  0.156216 -1.804749  0.113764  3.0
# 2013-01-05  0.269351  1.321942  0.714950  1.085879  4.0
# 2013-01-06 -0.538552 -0.460371  0.411290 -1.640347  5.0

# %%
df.at[datas[0], 'A'] = 0

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  1.144141  1.373960  0.723557  NaN
# 2013-01-02 -0.137733  2.751430  1.864549 -0.056077  1.0
# 2013-01-03 -0.756323  1.746032 -1.263350 -0.516354  2.0
# 2013-01-04  1.978866  0.156216 -1.804749  0.113764  3.0
# 2013-01-05  0.269351  1.321942  0.714950  1.085879  4.0
# 2013-01-06 -0.538552 -0.460371  0.411290 -1.640347  5.0

# %%
df.iat[0,1] = 0

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.000000  1.373960  0.723557  NaN
# 2013-01-02 -0.137733  2.751430  1.864549 -0.056077  1.0
# 2013-01-03 -0.756323  1.746032 -1.263350 -0.516354  2.0
# 2013-01-04  1.978866  0.156216 -1.804749  0.113764  3.0
# 2013-01-05  0.269351  1.321942  0.714950  1.085879  4.0
# 2013-01-06 -0.538552 -0.460371  0.411290 -1.640347  5.0

# %%
df.loc[:, 'D'] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  1.373960  5  NaN
# 2013-01-02 -0.137733  2.751430  1.864549  5  1.0
# 2013-01-03 -0.756323  1.746032 -1.263350  5  2.0
# 2013-01-04  1.978866  0.156216 -1.804749  5  3.0
# 2013-01-05  0.269351  1.321942  0.714950  5  4.0
# 2013-01-06 -0.538552 -0.460371  0.411290  5  5.0

# %%
df2 = df.copy()

# %%
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.373960 -5  NaN
# 2013-01-02 -0.137733 -2.751430 -1.864549 -5 -1.0
# 2013-01-03 -0.756323 -1.746032 -1.263350 -5 -2.0
# 2013-01-04 -1.978866 -0.156216 -1.804749 -5 -3.0
# 2013-01-05 -0.269351 -1.321942 -0.714950 -5 -4.0
# 2013-01-06 -0.538552 -0.460371 -0.411290 -5 -5.0

# %%
df1 = df.reindex(index=datas[0:4], columns=list(df.columns) + ['E'])

# %%
df1
# Out:
#                    A         B         C  D    F   E
# 2013-01-01  0.000000  0.000000  1.373960  5  NaN NaN
# 2013-01-02 -0.137733  2.751430  1.864549  5  1.0 NaN
# 2013-01-03 -0.756323  1.746032 -1.263350  5  2.0 NaN
# 2013-01-04  1.978866  0.156216 -1.804749  5  3.0 NaN

# %%
df1.loc[datas[0]:datas[1], 'E'] = 1

# %%
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  1.373960  5  NaN  1.0
# 2013-01-02 -0.137733  2.751430  1.864549  5  1.0  1.0
# 2013-01-03 -0.756323  1.746032 -1.263350  5  2.0  NaN
# 2013-01-04  1.978866  0.156216 -1.804749  5  3.0  NaN

# %%
df1.dropna(how='any')
# Out:
#                    A        B         C  D    F    E
# 2013-01-02 -0.137733  2.75143  1.864549  5  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  1.373960  5  5.0  1.0
# 2013-01-02 -0.137733  2.751430  1.864549  5  1.0  1.0
# 2013-01-03 -0.756323  1.746032 -1.263350  5  2.0  5.0
# 2013-01-04  1.978866  0.156216 -1.804749  5  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  1.373960  5  NaN
# 2013-01-02 -0.137733  2.751430  1.864549  5  1.0
# 2013-01-03 -0.756323  1.746032 -1.263350  5  2.0
# 2013-01-04  1.978866  0.156216 -1.804749  5  3.0
# 2013-01-05  0.269351  1.321942  0.714950  5  4.0
# 2013-01-06 -0.538552 -0.460371  0.411290  5  5.0

# %%
df.mean()
# Out:
# A    0.135935
# B    0.919208
# C    0.216108
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.593490
# 2013-01-02    2.095649
# 2013-01-03    1.345272
# 2013-01-04    1.666067
# 2013-01-05    2.261248
# 2013-01-06    1.882473
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=datas).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.756323  0.746032 -2.263350  4.0  1.0
# 2013-01-04 -1.021134 -2.843784 -4.804749  2.0  0.0
# 2013-01-05 -4.730649 -3.678058 -4.285050  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000  1.373960   5   NaN
# 2013-01-02 -0.137733  2.751430  3.238509  10   1.0
# 2013-01-03 -0.894055  4.497462  1.975158  15   3.0
# 2013-01-04  1.084811  4.653678  0.170409  20   6.0
# 2013-01-05  1.354162  5.975620  0.885359  25  10.0
# 2013-01-06  0.815610  5.515249  1.296649  30  15.0

# %%
np.cumsum
# Out:
# <function numpy.core.fromnumeric.cumsum>

# %%
s = pd.Series(np.random.randint(0,7,size=10))

# %%
s
# Out:
# 0    3
# 1    2
# 2    2
# 3    1
# 4    5
# 5    5
# 6    5
# 7    5
# 8    0
# 9    6
# dtype: int64

# %%
s.value_counts(0)
# Out:
# 5    4
# 2    2
# 6    1
# 3    1
# 1    1
# 0    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'dog', 'cat'])

# %%
s
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5     NaN
# 6     dog
# 7     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df
# Out:
#           0         1         2         3
# 0  0.244910 -0.511551  0.609944 -1.274210
# 1 -0.256576  1.060987  0.850407 -1.080033
# 2 -0.874497  0.029248 -0.006937 -1.768034
# 3 -0.693693 -0.324349  0.663219 -1.145702
# 4 -0.873145  0.468384 -0.353208 -0.291789
# 5  0.419216  0.045489 -0.731980  0.023429
# 6 -1.908196 -0.280144  0.257776 -0.264855
# 7 -0.993641 -0.321793 -0.595467 -1.051514
# 8  0.295062 -1.350714  2.335703  1.744217
# 9  0.035889 -0.901100 -1.773147 -1.838284

# %%
df[:3]
# Out:
#           0         1         2         3
# 0  0.244910 -0.511551  0.609944 -1.274210
# 1 -0.256576  1.060987  0.850407 -1.080033
# 2 -0.874497  0.029248 -0.006937 -1.768034

# %%
pieces = [df[:3], df[3:7], df[7:]]

# %%
pieces
# Out:
# [          0         1         2         3
#  0  0.244910 -0.511551  0.609944 -1.274210
#  1 -0.256576  1.060987  0.850407 -1.080033
#  2 -0.874497  0.029248 -0.006937 -1.768034,
#            0         1         2         3
#  3 -0.693693 -0.324349  0.663219 -1.145702
#  4 -0.873145  0.468384 -0.353208 -0.291789
#  5  0.419216  0.045489 -0.731980  0.023429
#  6 -1.908196 -0.280144  0.257776 -0.264855,
#            0         1         2         3
#  7 -0.993641 -0.321793 -0.595467 -1.051514
#  8  0.295062 -1.350714  2.335703  1.744217
#  9  0.035889 -0.901100 -1.773147 -1.838284]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.244910 -0.511551  0.609944 -1.274210
# 1 -0.256576  1.060987  0.850407 -1.080033
# 2 -0.874497  0.029248 -0.006937 -1.768034
# 3 -0.693693 -0.324349  0.663219 -1.145702
# 4 -0.873145  0.468384 -0.353208 -0.291789
# 5  0.419216  0.045489 -0.731980  0.023429
# 6 -1.908196 -0.280144  0.257776 -0.264855
# 7 -0.993641 -0.321793 -0.595467 -1.051514
# 8  0.295062 -1.350714  2.335703  1.744217
# 9  0.035889 -0.901100 -1.773147 -1.838284

# %%
left = pd.DataFrame({'key': ['foo', 'foo'],
                    'lval': [1,2]})
right = pd.DataFrame({'key': ['foo', 'foo'],
                    'rval': [4,5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo', 'bar'],
                    'lval': [1,2]})
right = pd.DataFrame({'key': ['foo', 'bar'],
                     'rval': [4,5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])

# %%
df
# Out:
#           A         B         C         D
# 0  0.060093 -4.423286  1.304140 -0.088604
# 1  0.064908 -0.685868  1.197039 -0.449025
# 2  1.381226  0.931706 -0.592601  0.566042
# 3 -0.246663  1.769678  0.857015  1.828764
# 4 -0.066209 -0.800482  0.741974 -0.649345
# 5 -0.991152 -1.163584  0.173587  1.547076
# 6  0.838711 -0.600190  0.143220  0.702929
# 7  1.072948  0.748917  1.492112  0.131650

# %%
s = df.iloc[3]

# %%
s
# Out:
# A   -0.246663
# B    1.769678
# C    0.857015
# D    1.828764
# Name: 3, dtype: float64

# %%
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  0.060093 -4.423286  1.304140 -0.088604
# 1  0.064908 -0.685868  1.197039 -0.449025
# 2  1.381226  0.931706 -0.592601  0.566042
# 3 -0.246663  1.769678  0.857015  1.828764
# 4 -0.066209 -0.800482  0.741974 -0.649345
# 5 -0.991152 -1.163584  0.173587  1.547076
# 6  0.838711 -0.600190  0.143220  0.702929
# 7  1.072948  0.748917  1.492112  0.131650
# 8 -0.246663  1.769678  0.857015  1.828764

# %%
df = pd.DataFrame({
    'A': ['foo', 'bar', 'foo', 'bar',
         'foo', 'bar', 'foo', 'foo'],
    'B': ['one', 'one', 'two', 'three',
         'one', 'one', 'two', 'three'],
    'C': np.random.randn(8),
    'D': np.random.randn(8)
})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -2.135971 -0.448750
# 1  bar    one  0.222406 -0.251786
# 2  foo    two  1.609076 -0.433261
# 3  bar  three -0.649156 -0.811086
# 4  foo    one -0.322173 -0.684512
# 5  bar    one  2.118954  0.961350
# 6  foo    two -1.535609 -0.307347
# 7  foo  three  0.109330  1.196978

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one    2.341360  0.709563
#     three -0.649156 -0.811086
# foo one   -2.458143 -1.133263
#     three  0.109330  1.196978
#     two    0.073467 -0.740608

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                    'foo', 'foo', 'qux', 'qux'],
                   ['one', 'two', 'one', 'two',
                   'one', 'two', 'one', 'two']]))

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])

# %%
index
# Out:
# MultiIndex(levels=[['bar', 'baz', 'foo', 'qux'], ['one', 'two']],
#            labels=[[0, 0, 1, 1, 2, 2, 3, 3], [0, 1, 0, 1, 0, 1, 0, 1]],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8,2), index=index, columns=['A','B'])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one     0.236288  0.067836
#       two     0.017911  1.289647
# baz   one     0.086238 -1.152481
#       two     0.524415  0.160293

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A    0.236288
#                B    0.067836
#        two     A    0.017911
#                B    1.289647
# baz    one     A    0.086238
#                B   -1.152481
#        two     A    0.524415
#                B    0.160293
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.236288  0.067836
#       two     0.017911  1.289647
# baz   one     0.086238 -1.152481
#       two     0.524415  0.160293

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.236288  0.017911
#       B  0.067836  1.289647
# baz   A  0.086238  0.524415
#       B -1.152481  0.160293

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  0.236288  0.086238
#        B  0.067836 -1.152481
# two    A  0.017911  0.524415
#        B  1.289647  0.160293

# %%
df = pd.DataFrame({
    'A': ['one', 'one', 'two', 'three'] * 3,
    'B': ['A', 'B', 'C'] * 4,
    'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
    'D': np.random.randn(12),
    'E': np.random.randn(12)
})

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  1.977313 -1.737558
# 1     one  B  foo  2.002594 -0.812113
# 2     two  C  foo -0.537848  0.985584
# 3   three  A  bar -0.875374 -1.247471
# 4     one  B  bar -0.457381  0.179455
# 5     one  C  bar -1.022762 -1.160785
# 6     two  A  foo  1.349111 -0.194924
# 7   three  B  foo -0.683085 -0.010913
# 8     one  C  foo -0.309431 -1.399506
# 9     one  A  bar -1.335166 -0.309313
# 10    two  B  bar  0.172291  1.298782
# 11  three  C  bar -1.329969  0.582610

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -1.335166  1.977313
#       B -0.457381  2.002594
#       C -1.022762 -0.309431
# three A -0.875374       NaN
#       B       NaN -0.683085
#       C -1.329969       NaN
# two   A       NaN  1.349111
#       B  0.172291       NaN
#       C       NaN -0.537848

# %%
df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
                          "bar", "bar", "bar", "bar"],
                    "B": ["one", "one", "one", "two", "two",
                          "one", "one", "two", "two"],
                    "C": ["small", "large", "large", "small",
                          "small", "large", "small", "small",
                          "large"],
                    "D": [1, 2, 2, 3, 3, 4, 5, 6, 7]})

# %%
df
# Out:
#      A    B      C  D
# 0  foo  one  small  1
# 1  foo  one  large  2
# 2  foo  one  large  2
# 3  foo  two  small  3
# 4  foo  two  small  3
# 5  bar  one  large  4
# 6  bar  one  small  5
# 7  bar  two  small  6
# 8  bar  two  large  7

# %%
table = pd.pivot_table(df, values='D', index=['A','B'],
                      columns=['C'], aggfunc=np.sum)

# %%
table
# Out:
# C        large  small
# A   B
# bar one    4.0    5.0
#     two    7.0    6.0
# foo one    4.0    1.0
#     two    NaN    6.0

# %%
table = pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'],
                      aggfunc={'D': np.mean,
                              'E': [min, max, np.mean]})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-140-46a154d270f6> in <module>()
#       1 table = pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'],
#       2                       aggfunc={'D': np.mean,
# ----> 3                               'E': [min, max, np.mean]})
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      59         for i in values:
#      60             if i not in data:
# ---> 61                 raise KeyError(i)
#      62
#      63         to_filter = []
#
# KeyError: 'E'

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
rng
# Out:
# DatetimeIndex(['2012-01-01 00:00:00', '2012-01-01 00:00:01',
#                '2012-01-01 00:00:02', '2012-01-01 00:00:03',
#                '2012-01-01 00:00:04', '2012-01-01 00:00:05',
#                '2012-01-01 00:00:06', '2012-01-01 00:00:07',
#                '2012-01-01 00:00:08', '2012-01-01 00:00:09',
#                '2012-01-01 00:00:10', '2012-01-01 00:00:11',
#                '2012-01-01 00:00:12', '2012-01-01 00:00:13',
#                '2012-01-01 00:00:14', '2012-01-01 00:00:15',
#                '2012-01-01 00:00:16', '2012-01-01 00:00:17',
#                '2012-01-01 00:00:18', '2012-01-01 00:00:19',
#                '2012-01-01 00:00:20', '2012-01-01 00:00:21',
#                '2012-01-01 00:00:22', '2012-01-01 00:00:23',
#                '2012-01-01 00:00:24', '2012-01-01 00:00:25',
#                '2012-01-01 00:00:26', '2012-01-01 00:00:27',
#                '2012-01-01 00:00:28', '2012-01-01 00:00:29',
#                '2012-01-01 00:00:30', '2012-01-01 00:00:31',
#                '2012-01-01 00:00:32', '2012-01-01 00:00:33',
#                '2012-01-01 00:00:34', '2012-01-01 00:00:35',
#                '2012-01-01 00:00:36', '2012-01-01 00:00:37',
#                '2012-01-01 00:00:38', '2012-01-01 00:00:39',
#                '2012-01-01 00:00:40', '2012-01-01 00:00:41',
#                '2012-01-01 00:00:42', '2012-01-01 00:00:43',
#                '2012-01-01 00:00:44', '2012-01-01 00:00:45',
#                '2012-01-01 00:00:46', '2012-01-01 00:00:47',
#                '2012-01-01 00:00:48', '2012-01-01 00:00:49',
#                '2012-01-01 00:00:50', '2012-01-01 00:00:51',
#                '2012-01-01 00:00:52', '2012-01-01 00:00:53',
#                '2012-01-01 00:00:54', '2012-01-01 00:00:55',
#                '2012-01-01 00:00:56', '2012-01-01 00:00:57',
#                '2012-01-01 00:00:58', '2012-01-01 00:00:59',
#                '2012-01-01 00:01:00', '2012-01-01 00:01:01',
#                '2012-01-01 00:01:02', '2012-01-01 00:01:03',
#                '2012-01-01 00:01:04', '2012-01-01 00:01:05',
#                '2012-01-01 00:01:06', '2012-01-01 00:01:07',
#                '2012-01-01 00:01:08', '2012-01-01 00:01:09',
#                '2012-01-01 00:01:10', '2012-01-01 00:01:11',
#                '2012-01-01 00:01:12', '2012-01-01 00:01:13',
#                '2012-01-01 00:01:14', '2012-01-01 00:01:15',
#                '2012-01-01 00:01:16', '2012-01-01 00:01:17',
#                '2012-01-01 00:01:18', '2012-01-01 00:01:19',
#                '2012-01-01 00:01:20', '2012-01-01 00:01:21',
#                '2012-01-01 00:01:22', '2012-01-01 00:01:23',
#                '2012-01-01 00:01:24', '2012-01-01 00:01:25',
#                '2012-01-01 00:01:26', '2012-01-01 00:01:27',
#                '2012-01-01 00:01:28', '2012-01-01 00:01:29',
#                '2012-01-01 00:01:30', '2012-01-01 00:01:31',
#                '2012-01-01 00:01:32', '2012-01-01 00:01:33',
#                '2012-01-01 00:01:34', '2012-01-01 00:01:35',
#                '2012-01-01 00:01:36', '2012-01-01 00:01:37',
#                '2012-01-01 00:01:38', '2012-01-01 00:01:39'],
#               dtype='datetime64[ns]', freq='S')

# %%
ts
# Out:
# 2012-01-01 00:00:00    156
# 2012-01-01 00:00:01    318
# 2012-01-01 00:00:02    427
# 2012-01-01 00:00:03     81
# 2012-01-01 00:00:04    444
# 2012-01-01 00:00:05     70
# 2012-01-01 00:00:06    443
# 2012-01-01 00:00:07    237
# 2012-01-01 00:00:08     87
# 2012-01-01 00:00:09    417
# 2012-01-01 00:00:10    102
# 2012-01-01 00:00:11    264
# 2012-01-01 00:00:12    435
# 2012-01-01 00:00:13    389
# 2012-01-01 00:00:14    331
# 2012-01-01 00:00:15    351
# 2012-01-01 00:00:16    380
# 2012-01-01 00:00:17     79
# 2012-01-01 00:00:18     19
# 2012-01-01 00:00:19    232
# 2012-01-01 00:00:20     43
# 2012-01-01 00:00:21     54
# 2012-01-01 00:00:22    405
# 2012-01-01 00:00:23    266
# 2012-01-01 00:00:24    330
# 2012-01-01 00:00:25    260
# 2012-01-01 00:00:26     49
# 2012-01-01 00:00:27    160
# 2012-01-01 00:00:28    166
# 2012-01-01 00:00:29    223
#                       ...
# 2012-01-01 00:01:10    480
# 2012-01-01 00:01:11    319
# 2012-01-01 00:01:12    450
# 2012-01-01 00:01:13    115
# 2012-01-01 00:01:14    433
# 2012-01-01 00:01:15    450
# 2012-01-01 00:01:16    148
# 2012-01-01 00:01:17    287
# 2012-01-01 00:01:18     91
# 2012-01-01 00:01:19    439
# 2012-01-01 00:01:20     62
# 2012-01-01 00:01:21    168
# 2012-01-01 00:01:22     60
# 2012-01-01 00:01:23      7
# 2012-01-01 00:01:24    472
# 2012-01-01 00:01:25    158
# 2012-01-01 00:01:26    104
# 2012-01-01 00:01:27     69
# 2012-01-01 00:01:28    158
# 2012-01-01 00:01:29    276
# 2012-01-01 00:01:30    493
# 2012-01-01 00:01:31    152
# 2012-01-01 00:01:32    452
# 2012-01-01 00:01:33    393
# 2012-01-01 00:01:34    253
# 2012-01-01 00:01:35    156
# 2012-01-01 00:01:36    400
# 2012-01-01 00:01:37    232
# 2012-01-01 00:01:38    241
# 2012-01-01 00:01:39    283
# Freq: S, Length: 100, dtype: int64

# %%
ts_utc = ts.tz_localize('UTC')

# %%
ts_utc
# Out:
# 2012-01-01 00:00:00+00:00    156
# 2012-01-01 00:00:01+00:00    318
# 2012-01-01 00:00:02+00:00    427
# 2012-01-01 00:00:03+00:00     81
# 2012-01-01 00:00:04+00:00    444
# 2012-01-01 00:00:05+00:00     70
# 2012-01-01 00:00:06+00:00    443
# 2012-01-01 00:00:07+00:00    237
# 2012-01-01 00:00:08+00:00     87
# 2012-01-01 00:00:09+00:00    417
# 2012-01-01 00:00:10+00:00    102
# 2012-01-01 00:00:11+00:00    264
# 2012-01-01 00:00:12+00:00    435
# 2012-01-01 00:00:13+00:00    389
# 2012-01-01 00:00:14+00:00    331
# 2012-01-01 00:00:15+00:00    351
# 2012-01-01 00:00:16+00:00    380
# 2012-01-01 00:00:17+00:00     79
# 2012-01-01 00:00:18+00:00     19
# 2012-01-01 00:00:19+00:00    232
# 2012-01-01 00:00:20+00:00     43
# 2012-01-01 00:00:21+00:00     54
# 2012-01-01 00:00:22+00:00    405
# 2012-01-01 00:00:23+00:00    266
# 2012-01-01 00:00:24+00:00    330
# 2012-01-01 00:00:25+00:00    260
# 2012-01-01 00:00:26+00:00     49
# 2012-01-01 00:00:27+00:00    160
# 2012-01-01 00:00:28+00:00    166
# 2012-01-01 00:00:29+00:00    223
#                             ...
# 2012-01-01 00:01:10+00:00    480
# 2012-01-01 00:01:11+00:00    319
# 2012-01-01 00:01:12+00:00    450
# 2012-01-01 00:01:13+00:00    115
# 2012-01-01 00:01:14+00:00    433
# 2012-01-01 00:01:15+00:00    450
# 2012-01-01 00:01:16+00:00    148
# 2012-01-01 00:01:17+00:00    287
# 2012-01-01 00:01:18+00:00     91
# 2012-01-01 00:01:19+00:00    439
# 2012-01-01 00:01:20+00:00     62
# 2012-01-01 00:01:21+00:00    168
# 2012-01-01 00:01:22+00:00     60
# 2012-01-01 00:01:23+00:00      7
# 2012-01-01 00:01:24+00:00    472
# 2012-01-01 00:01:25+00:00    158
# 2012-01-01 00:01:26+00:00    104
# 2012-01-01 00:01:27+00:00     69
# 2012-01-01 00:01:28+00:00    158
# 2012-01-01 00:01:29+00:00    276
# 2012-01-01 00:01:30+00:00    493
# 2012-01-01 00:01:31+00:00    152
# 2012-01-01 00:01:32+00:00    452
# 2012-01-01 00:01:33+00:00    393
# 2012-01-01 00:01:34+00:00    253
# 2012-01-01 00:01:35+00:00    156
# 2012-01-01 00:01:36+00:00    400
# 2012-01-01 00:01:37+00:00    232
# 2012-01-01 00:01:38+00:00    241
# 2012-01-01 00:01:39+00:00    283
# Freq: S, Length: 100, dtype: int64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2011-12-31 19:00:00-05:00    156
# 2011-12-31 19:00:01-05:00    318
# 2011-12-31 19:00:02-05:00    427
# 2011-12-31 19:00:03-05:00     81
# 2011-12-31 19:00:04-05:00    444
# 2011-12-31 19:00:05-05:00     70
# 2011-12-31 19:00:06-05:00    443
# 2011-12-31 19:00:07-05:00    237
# 2011-12-31 19:00:08-05:00     87
# 2011-12-31 19:00:09-05:00    417
# 2011-12-31 19:00:10-05:00    102
# 2011-12-31 19:00:11-05:00    264
# 2011-12-31 19:00:12-05:00    435
# 2011-12-31 19:00:13-05:00    389
# 2011-12-31 19:00:14-05:00    331
# 2011-12-31 19:00:15-05:00    351
# 2011-12-31 19:00:16-05:00    380
# 2011-12-31 19:00:17-05:00     79
# 2011-12-31 19:00:18-05:00     19
# 2011-12-31 19:00:19-05:00    232
# 2011-12-31 19:00:20-05:00     43
# 2011-12-31 19:00:21-05:00     54
# 2011-12-31 19:00:22-05:00    405
# 2011-12-31 19:00:23-05:00    266
# 2011-12-31 19:00:24-05:00    330
# 2011-12-31 19:00:25-05:00    260
# 2011-12-31 19:00:26-05:00     49
# 2011-12-31 19:00:27-05:00    160
# 2011-12-31 19:00:28-05:00    166
# 2011-12-31 19:00:29-05:00    223
#                             ...
# 2011-12-31 19:01:10-05:00    480
# 2011-12-31 19:01:11-05:00    319
# 2011-12-31 19:01:12-05:00    450
# 2011-12-31 19:01:13-05:00    115
# 2011-12-31 19:01:14-05:00    433
# 2011-12-31 19:01:15-05:00    450
# 2011-12-31 19:01:16-05:00    148
# 2011-12-31 19:01:17-05:00    287
# 2011-12-31 19:01:18-05:00     91
# 2011-12-31 19:01:19-05:00    439
# 2011-12-31 19:01:20-05:00     62
# 2011-12-31 19:01:21-05:00    168
# 2011-12-31 19:01:22-05:00     60
# 2011-12-31 19:01:23-05:00      7
# 2011-12-31 19:01:24-05:00    472
# 2011-12-31 19:01:25-05:00    158
# 2011-12-31 19:01:26-05:00    104
# 2011-12-31 19:01:27-05:00     69
# 2011-12-31 19:01:28-05:00    158
# 2011-12-31 19:01:29-05:00    276
# 2011-12-31 19:01:30-05:00    493
# 2011-12-31 19:01:31-05:00    152
# 2011-12-31 19:01:32-05:00    452
# 2011-12-31 19:01:33-05:00    393
# 2011-12-31 19:01:34-05:00    253
# 2011-12-31 19:01:35-05:00    156
# 2011-12-31 19:01:36-05:00    400
# 2011-12-31 19:01:37-05:00    232
# 2011-12-31 19:01:38-05:00    241
# 2011-12-31 19:01:39-05:00    283
# Freq: S, Length: 100, dtype: int64

# %%
df = pd.DataFrame({
    "id": [1,2,3,4,5,6],
    "raw_grade": ['a','b','c','d','e','f']
})

# %%
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         c
# 3   4         d
# 4   5         e
# 5   6         f

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df
# Out:
#    id raw_grade grade
# 0   1         a     a
# 1   2         b     b
# 2   3         c     c
# 3   4         d     d
# 4   5         e     e
# 5   6         f     f

# %%
# df["grade"].cat.categories = ['very good', 'good', 'very bad']

# %%
df.groupby("grade").size()
# Out:
# grade
# a    1
# b    1
# c    1
# d    1
# e    1
# f    1
# dtype: int64

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts
# Out:
# 2000-01-01   -1.685652
# 2000-01-02    1.153873
# 2000-01-03   -1.915245
# 2000-01-04   -0.200969
# 2000-01-05    0.113134
# 2000-01-06   -0.646942
# 2000-01-07   -2.142671
# 2000-01-08    2.013045
# 2000-01-09   -1.828179
# 2000-01-10   -1.308609
# 2000-01-11   -0.942536
# 2000-01-12   -0.785476
# 2000-01-13    0.012617
# 2000-01-14    3.113317
# 2000-01-15    0.815190
# 2000-01-16   -0.200920
# 2000-01-17    0.137410
# 2000-01-18   -0.494889
# 2000-01-19    0.185619
# 2000-01-20   -1.954004
# 2000-01-21    0.547693
# 2000-01-22   -1.229044
# 2000-01-23    0.541745
# 2000-01-24   -0.713398
# 2000-01-25   -0.845278
# 2000-01-26    0.777083
# 2000-01-27   -0.190415
# 2000-01-28    0.166170
# 2000-01-29   -0.442142
# 2000-01-30    0.447700
#                 ...
# 2002-08-28    0.427455
# 2002-08-29   -0.983700
# 2002-08-30    0.721549
# 2002-08-31    2.041072
# 2002-09-01    0.390124
# 2002-09-02   -0.940023
# 2002-09-03   -1.197475
# 2002-09-04   -2.437344
# 2002-09-05    0.897731
# 2002-09-06   -0.213998
# 2002-09-07   -0.177655
# 2002-09-08   -1.923132
# 2002-09-09   -0.443700
# 2002-09-10   -0.330636
# 2002-09-11   -0.486305
# 2002-09-12    1.618665
# 2002-09-13    1.437634
# 2002-09-14    0.401315
# 2002-09-15   -1.464168
# 2002-09-16   -0.101683
# 2002-09-17    0.200823
# 2002-09-18   -0.157695
# 2002-09-19   -0.365309
# 2002-09-20   -1.528572
# 2002-09-21   -1.363476
# 2002-09-22   -0.206985
# 2002-09-23   -0.092790
# 2002-09-24   -0.566885
# 2002-09-25    0.002369
# 2002-09-26   -1.363908
# Freq: D, Length: 1000, dtype: float64

# %%
ts = ts.cumsum()

# %%
ts
# Out:
# 2000-01-01    -1.685652
# 2000-01-02    -0.531779
# 2000-01-03    -2.447024
# 2000-01-04    -2.647992
# 2000-01-05    -2.534858
# 2000-01-06    -3.181800
# 2000-01-07    -5.324470
# 2000-01-08    -3.311426
# 2000-01-09    -5.139605
# 2000-01-10    -6.448213
# 2000-01-11    -7.390750
# 2000-01-12    -8.176226
# 2000-01-13    -8.163608
# 2000-01-14    -5.050291
# 2000-01-15    -4.235101
# 2000-01-16    -4.436021
# 2000-01-17    -4.298612
# 2000-01-18    -4.793501
# 2000-01-19    -4.607882
# 2000-01-20    -6.561886
# 2000-01-21    -6.014193
# 2000-01-22    -7.243237
# 2000-01-23    -6.701492
# 2000-01-24    -7.414890
# 2000-01-25    -8.260168
# 2000-01-26    -7.483085
# 2000-01-27    -7.673500
# 2000-01-28    -7.507330
# 2000-01-29    -7.949471
# 2000-01-30    -7.501771
#                 ...
# 2002-08-28   -42.813022
# 2002-08-29   -43.796722
# 2002-08-30   -43.075173
# 2002-08-31   -41.034101
# 2002-09-01   -40.643977
# 2002-09-02   -41.584000
# 2002-09-03   -42.781475
# 2002-09-04   -45.218819
# 2002-09-05   -44.321088
# 2002-09-06   -44.535086
# 2002-09-07   -44.712741
# 2002-09-08   -46.635873
# 2002-09-09   -47.079573
# 2002-09-10   -47.410209
# 2002-09-11   -47.896514
# 2002-09-12   -46.277849
# 2002-09-13   -44.840215
# 2002-09-14   -44.438900
# 2002-09-15   -45.903068
# 2002-09-16   -46.004751
# 2002-09-17   -45.803928
# 2002-09-18   -45.961623
# 2002-09-19   -46.326932
# 2002-09-20   -47.855504
# 2002-09-21   -49.218980
# 2002-09-22   -49.425965
# 2002-09-23   -49.518755
# 2002-09-24   -50.085640
# 2002-09-25   -50.083272
# 2002-09-26   -51.447180
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                 columns=['A', 'B', 'C', 'D'])

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01 -0.714328  0.514876 -0.468779 -1.773393
# 2000-01-02  0.421115  1.297448  1.431650  0.978281
# 2000-01-03  1.687549 -0.208971  0.062783  0.567529
# 2000-01-04 -0.510256 -0.563426 -1.247866  0.425231
# 2000-01-05  0.276666  0.150251  0.390412 -0.417749
# 2000-01-06 -0.300355 -0.713156 -0.186611  0.027642
# 2000-01-07 -1.184307  0.192736 -1.765358  1.118923
# 2000-01-08 -1.537714 -0.968484 -0.318572  0.176220
# 2000-01-09 -0.233283  1.492160 -1.024449  0.560276
# 2000-01-10 -0.269107 -0.974010  0.097364  0.381346
# 2000-01-11  1.439082  1.581366 -0.014550  0.631127
# 2000-01-12  1.987961 -0.075705  0.441159 -0.407127
# 2000-01-13  2.264353  1.560417 -0.266562  0.602596
# 2000-01-14 -0.209569  0.599342  0.839832 -2.721522
# 2000-01-15  0.410933 -0.008425 -0.840957 -1.489488
# 2000-01-16 -0.833863 -0.648499  0.974086  0.556009
# 2000-01-17 -0.248606  1.368806  0.215168  1.330024
# 2000-01-18  1.498701 -0.081397  0.411653  0.314683
# 2000-01-19  0.892563 -0.439372  0.452101  0.868882
# 2000-01-20 -1.301958 -0.940657 -0.817113  2.347613
# 2000-01-21  0.244925  0.221911 -0.449996 -0.490841
# 2000-01-22 -0.398609 -0.427050 -0.165567 -1.037486
# 2000-01-23 -0.880057  0.061152 -0.739612 -0.454248
# 2000-01-24  0.134804  0.958982  0.052672 -0.508434
# 2000-01-25 -1.706139  1.222040  0.591941  0.371564
# 2000-01-26 -0.824846 -1.321049 -0.121760  0.876559
# 2000-01-27  0.106254  0.595298  0.999628 -0.334160
# 2000-01-28  1.070592  1.148564  1.827682 -0.470406
# 2000-01-29 -0.028850  0.575867  0.929273  0.407642
# 2000-01-30 -1.156293  0.801909 -0.829793 -0.382969
# ...              ...       ...       ...       ...
# 2002-08-28  1.082939 -0.811380  1.272078  0.901840
# 2002-08-29 -0.991141  0.710685 -0.310939  0.402867
# 2002-08-30  0.086494 -0.019389  0.564779  0.158953
# 2002-08-31 -0.735295  1.427262  0.064447  0.556362
# 2002-09-01  0.631268  0.715716 -1.169607  0.649451
# 2002-09-02  1.241327  1.062076  0.356879 -1.059979
# 2002-09-03 -1.400495  0.344274  0.332086 -0.331251
# 2002-09-04 -0.698517  1.282479  0.820691 -0.155258
# 2002-09-05 -0.327691  0.057436  0.248354 -0.207830
# 2002-09-06  0.185851 -0.628189 -0.158553  0.056808
# 2002-09-07  0.713184 -1.509932 -0.539963  0.310342
# 2002-09-08  0.846144  0.129046 -0.025223  0.755076
# 2002-09-09  0.313657  0.293498  0.051125  1.039524
# 2002-09-10 -0.562747 -0.858140 -0.680741  0.017085
# 2002-09-11 -0.069959 -0.257713  0.320759  1.668076
# 2002-09-12 -1.638001  0.902298 -1.098901 -0.567198
# 2002-09-13 -0.226224 -0.130080  1.213096 -0.976615
# 2002-09-14  0.245183 -0.334158 -0.619699  0.804521
# 2002-09-15  0.855685 -0.035975 -1.247091  0.374034
# 2002-09-16 -0.274485 -0.820941 -0.195623 -0.774412
# 2002-09-17 -0.932758 -0.524287  0.176568  0.493732
# 2002-09-18 -0.195199  0.374498  0.122343  2.967897
# 2002-09-19  0.705657  1.593486  0.184803  0.687962
# 2002-09-20  1.211566 -1.514604  1.139930 -0.067626
# 2002-09-21  1.943773  0.107865 -0.387712 -0.150525
# 2002-09-22 -1.021034  1.116029 -1.261252  0.610912
# 2002-09-23 -1.190759 -0.385653 -1.217592 -0.380219
# 2002-09-24 -0.150804 -0.625526 -0.864115  0.794939
# 2002-09-25  1.959639 -0.255899 -0.124808  0.580596
# 2002-09-26  0.200899  2.836278  0.124053 -0.276003
#
# [1000 rows x 4 columns]

# %%
df = df.cumsum()

# %%
df
# Out:
#                     A          B          C         D
# 2000-01-01  -0.714328   0.514876  -0.468779 -1.773393
# 2000-01-02  -0.293214   1.812325   0.962871 -0.795112
# 2000-01-03   1.394336   1.603353   1.025654 -0.227583
# 2000-01-04   0.884080   1.039927  -0.222212  0.197648
# 2000-01-05   1.160746   1.190179   0.168201 -0.220101
# 2000-01-06   0.860391   0.477023  -0.018410 -0.192459
# 2000-01-07  -0.323916   0.669759  -1.783768  0.926464
# 2000-01-08  -1.861630  -0.298725  -2.102340  1.102684
# 2000-01-09  -2.094913   1.193435  -3.126789  1.662960
# 2000-01-10  -2.364019   0.219425  -3.029425  2.044306
# 2000-01-11  -0.924938   1.800791  -3.043975  2.675433
# 2000-01-12   1.063024   1.725086  -2.602815  2.268306
# 2000-01-13   3.327377   3.285503  -2.869378  2.870902
# 2000-01-14   3.117808   3.884844  -2.029545  0.149380
# 2000-01-15   3.528741   3.876420  -2.870502 -1.340108
# 2000-01-16   2.694878   3.227921  -1.896416 -0.784099
# 2000-01-17   2.446271   4.596727  -1.681248  0.545926
# 2000-01-18   3.944972   4.515330  -1.269596  0.860609
# 2000-01-19   4.837535   4.075958  -0.817494  1.729491
# 2000-01-20   3.535578   3.135301  -1.634607  4.077104
# 2000-01-21   3.780502   3.357212  -2.084604  3.586264
# 2000-01-22   3.381894   2.930162  -2.250171  2.548778
# 2000-01-23   2.501837   2.991314  -2.989782  2.094531
# 2000-01-24   2.636641   3.950296  -2.937110  1.586096
# 2000-01-25   0.930501   5.172336  -2.345169  1.957660
# 2000-01-26   0.105656   3.851286  -2.466929  2.834219
# 2000-01-27   0.211909   4.446584  -1.467301  2.500059
# 2000-01-28   1.282502   5.595148   0.360381  2.029653
# 2000-01-29   1.253652   6.171016   1.289653  2.437295
# 2000-01-30   0.097358   6.972925   0.459860  2.054326
# ...               ...        ...        ...       ...
# 2002-08-28 -12.812499  19.337332 -29.051178 -9.541685
# 2002-08-29 -13.803640  20.048016 -29.362116 -9.138818
# 2002-08-30 -13.717145  20.028627 -28.797337 -8.979865
# 2002-08-31 -14.452441  21.455890 -28.732889 -8.423503
# 2002-09-01 -13.821173  22.171606 -29.902497 -7.774052
# 2002-09-02 -12.579846  23.233682 -29.545617 -8.834031
# 2002-09-03 -13.980341  23.577956 -29.213532 -9.165282
# 2002-09-04 -14.678858  24.860435 -28.392841 -9.320540
# 2002-09-05 -15.006549  24.917871 -28.144486 -9.528370
# 2002-09-06 -14.820698  24.289682 -28.303039 -9.471562
# 2002-09-07 -14.107515  22.779750 -28.843003 -9.161220
# 2002-09-08 -13.261371  22.908797 -28.868226 -8.406144
# 2002-09-09 -12.947714  23.202295 -28.817101 -7.366620
# 2002-09-10 -13.510462  22.344155 -29.497842 -7.349535
# 2002-09-11 -13.580420  22.086442 -29.177082 -5.681459
# 2002-09-12 -15.218421  22.988740 -30.275983 -6.248657
# 2002-09-13 -15.444645  22.858660 -29.062887 -7.225272
# 2002-09-14 -15.199462  22.524502 -29.682586 -6.420751
# 2002-09-15 -14.343777  22.488527 -30.929677 -6.046717
# 2002-09-16 -14.618262  21.667586 -31.125301 -6.821130
# 2002-09-17 -15.551019  21.143298 -30.948733 -6.327398
# 2002-09-18 -15.746218  21.517796 -30.826390 -3.359500
# 2002-09-19 -15.040562  23.111283 -30.641587 -2.671538
# 2002-09-20 -13.828996  21.596679 -29.501657 -2.739165
# 2002-09-21 -11.885223  21.704544 -29.889369 -2.889690
# 2002-09-22 -12.906257  22.820573 -31.150621 -2.278778
# 2002-09-23 -14.097015  22.434921 -32.368213 -2.658997
# 2002-09-24 -14.247819  21.809395 -33.232328 -1.864058
# 2002-09-25 -12.288180  21.553496 -33.357136 -1.283462
# 2002-09-26 -12.087280  24.389774 -33.233084 -1.559465
#
# [1000 rows x 4 columns]

# %%
plt.figure(); df.plot(); plt.legend(loc='best')

# %%
df.shape
# Out:
# (1000, 4)

# %%
plot_df = pd.DataFrame({
    'col1': [1, 3, 2, 4],
    'col2': [3, 6, 5, 1],
    'col3': [4, 7, 6, 2],
})

# %%
plot_df.plot()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('WEO_Data.csv')

# %%
data.columns
# Out:
# Index(['Country', 'Subject Descriptor', 'Units', 'Scale',
#        'Country/Series-specific Notes', '2015', 'Estimates Start After'],
#       dtype='object')

# %%
data[data['Country']=='Albania']
# Out:
#    Country                                 Subject Descriptor         Units  \
# 1  Albania  Gross domestic product per capita, current prices  U.S. dollars
#
#    Scale                      Country/Series-specific Notes      2015  \
# 1  Units  See notes for:  Gross domestic product, curren...  3,995.38
#
#    Estimates Start After
# 1                 2010.0

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df.rename(index=str, columns={"A": "a", "B": "c"})
# Out:
#    a  c
# 0  1  4
# 1  2  5
# 2  3  6

# %%
data = data.rename(index=str, columns={'2015': 'GDP'})

# %%
data[data['Country']=='China']
# Out:
#    Country                                 Subject Descriptor         Units  \
# 34   China  Gross domestic product per capita, current prices  U.S. dollars
#
#     Scale                      Country/Series-specific Notes       GDP  \
# 34  Units  See notes for:  Gross domestic product, curren...  7,989.72
#
#     Estimates Start After
# 34                 2015.0
